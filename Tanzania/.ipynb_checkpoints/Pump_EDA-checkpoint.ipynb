# %% [markdown]
# Download the training and testing datasets to our local directory.

# %%
import requests
import csv

urls = {
        'X_train' : "https://s3.amazonaws.com/drivendata/data/7/public/4910797b-ee55-40a7-8668-10efd5c1b960.csv",
        'y_train' : "https://s3.amazonaws.com/drivendata/data/7/public/0bf8bc6e-30d0-4c50-956a-603fc693d966.csv",
        'X_test' : "https://s3.amazonaws.com/drivendata/data/7/public/702ddfc5-68cd-4d1d-a0de-f5f566f76d91.csv",
        'y_test' : "https://s3.amazonaws.com/drivendata/data/7/public/SubmissionFormat.csv"
        }

for i in urls:
    r = requests.get(urls[i])

    text = r.iter_lines()

    reader = csv.reader(text, delimiter=',')

    mylist = list(reader)

    with open(str(i)+'.csv', 'wb') as fp:
        a = csv.writer(fp, delimiter=',')
        data = mylist
        a.writerows(data)

# %% [markdown]
# Load our train and test datasets into pandas.

# %%
import pandas as pd
import numpy as np

# %%
X_train = pd.read_csv('X_train.csv')
y_train = pd.read_csv('y_train.csv')
X_test = pd.read_csv('X_test.csv')

# %% [markdown]
# Let's inspect our target variable:

# %%
del y_train['id']

# %%
y_train['status_group'].value_counts(normalize = True)
# Out:
# functional                 0.543081
# non functional             0.384242
# functional needs repair    0.072677
# Name: status_group, dtype: float64

# %%
for i in X_train.columns:
    print i,',' ,'{:.1%}'.format(np.mean(X_train[i].isnull())),'nulls',',',type(X_train[i][0]), X_train[i].nunique()
# Out:
# date_recorded , 0.0% nulls , <class 'pandas.tslib.Timestamp'> 356
# gps_height , 0.0% nulls , <type 'numpy.int64'> 2428
# longitude , 0.0% nulls , <type 'numpy.float64'> 57516
# latitude , 0.0% nulls , <type 'numpy.float64'> 57517
# population , 0.0% nulls , <type 'numpy.int64'> 1049
# public_meeting , 0.0% nulls , <type 'numpy.bool_'> 2
# permit , 0.0% nulls , <type 'numpy.bool_'> 2
# year_recorded , 100.0% nulls , <type 'numpy.float64'> 5
# month_recorded , 100.0% nulls , <type 'numpy.float64'> 12
# funder__0 , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Abasia , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Acra , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Adb , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Adra , 0.0% nulls , <type 'numpy.float64'> 2
# funder__African Development Bank , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Ai , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Aict , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Amref , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Anglican Church , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Asb , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Bahewasa , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Bank , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Belgian Government , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Cafod , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Cct , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Cdtf , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Cefa , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Cefa-njombe , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Ces (gmbh) , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Ces(gmbh) , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Cipro/government , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Cmcr , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Community , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Concern , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Concern World Wide , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Danida , 0.0% nulls , <type 'numpy.float64'> 2
# funder__De , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Dfid , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Dhv\norp , 0.0% nulls , <type 'numpy.float64'> 2
# funder__District Council , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Dmdd , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Dwe , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Dwsp , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Dwssp , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Efg , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Ereto , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Eu/acra , 0.0% nulls , <type 'numpy.float64'> 2
# funder__European Union , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Fathe , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Father Bonifasi , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Fin Water , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Fini Water , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Finida German Tanzania Govt , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Finidagermantanzania Govt , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Finland , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Finland Government , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Finn Water , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Finw , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Floresta , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Fw , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Ga , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Germany , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Germany Republi , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Giz , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Go , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Government Of Tanzania , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Government/ World Bank , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Grumeti , 0.0% nulls , <type 'numpy.float64'> 2
# funder__Gtz , 0.0% nulls , <type 'numpy.float64'> 2
# funder__H , 0.0% nulls , <type 'numpy.float64'> 2
# funder__
 0.0% nulls , <type 'numpy.float64'> 2
# installer__Canop , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Ce , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Centr , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Central Government , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Central government , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Central govt , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Ch , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Co , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Commu , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Communit , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Community , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Consultant Engineer , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Cosmos Engineering , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Council , 0.0% nulls , <type 'numpy.float64'> 2
# installer__DA , 0.0% nulls , <type 'numpy.float64'> 2
# installer__DANID , 0.0% nulls , <type 'numpy.float64'> 2
# installer__DAWASCO , 0.0% nulls , <type 'numpy.float64'> 2
# installer__DDCA , 0.0% nulls , <type 'numpy.float64'> 2
# installer__DHV , 0.0% nulls , <type 'numpy.float64'> 2
# installer__DMDD , 0.0% nulls , <type 'numpy.float64'> 2
# installer__DW , 0.0% nulls , <type 'numpy.float64'> 2
# installer__DWE , 0.0% nulls , <type 'numpy.float64'> 2
# installer__DWSP , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Da , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Danid , 0.0% nulls , <type 'numpy.float64'> 2
# installer__District Water Department , 0.0% nulls , <type 'numpy.float64'> 2
# installer__District council , 0.0% nulls , <type 'numpy.float64'> 2
# installer__District water department , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Dmdd , 0.0% nulls , <type 'numpy.float64'> 2
# installer__EFG , 0.0% nulls , <type 'numpy.float64'> 2
# installer__FIN WATER , 0.0% nulls , <type 'numpy.float64'> 2
# installer__FINI WATER , 0.0% nulls , <type 'numpy.float64'> 2
# installer__FINN WATER , 0.0% nulls , <type 'numpy.float64'> 2
# installer__FLORESTA , 0.0% nulls , <type 'numpy.float64'> 2
# installer__FURAHIA TRADING , 0.0% nulls , <type 'numpy.float64'> 2
# installer__FW , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Fathe , 0.0% nulls , <type 'numpy.float64'> 2
# installer__FinW , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Fini Water , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Fini water , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Finland Government , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Finwater , 0.0% nulls , <type 'numpy.float64'> 2
# installer__GEOTAN , 0.0% nulls , <type 'numpy.float64'> 2
# installer__GOVER , 0.0% nulls , <type 'numpy.float64'> 2
# installer__GOVERN , 0.0% nulls , <type 'numpy.float64'> 2
# installer__GOVERNMENT , 0.0% nulls , <type 'numpy.float64'> 2
# installer__GRUMETI , 0.0% nulls , <type 'numpy.float64'> 2
# installer__GTZ , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Ga , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Gove , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Government , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Gwasco L , 0.0% nulls , <type 'numpy.float64'> 2
# installer__H , 0.0% nulls , <type 'numpy.float64'> 2
# installer__HAPA SINGIDA , 0.0% nulls , <type 'numpy.float64'> 2
# installer__HE , 0.0% nulls , <type 'numpy.float64'> 2
# installer__HOLLAND , 0.0% nulls , <type 'numpy.float64'> 2
# installer__HSW , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Halmashauri wilaya , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Halmashauri ya wilaya sikonge , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Hans , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Hesawa , 0.0% nulls , <type 'numpy.float64'> 2
# installer__ICS , 0.0% nulls , <type 'numpy.float64'> 2
# installer__IFAD , 0.0% nulls , <type 'numpy.float64'> 2
# installer__ISF/TACARE , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Idara ya maji , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Inter , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Ir , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Is , 0.0% nulls , <type 'numpy.float64'> 2
# installer__JAICA , 0.0% nulls , <type 'numpy.float64'> 2
# installer__JUIN CO , 0.0% nulls , <type 'numpy.float64'> 2
# installer__KILI WATER , 0.0% nulls , <type 'numpy.float64'> 2
# installer__KIM KIM CONSTRUCTION , 0.0% nulls , <type 'numpy.float64'> 2
# installer__KIUMA , 0.0% nulls , <type 'numpy.float64'> 2
# installer__KKKT , 0.0% nulls , <type 'numpy.float64'> 2
# installer__KKKT CHURCH , 0.0% nulls , <type 'numpy.float64'> 2
# installer__KKKT-Dioces ya Pare , 0.0% nulls , <type 'numpy.float64'> 2
# installer__KUWAIT , 0.0% nulls , <type 'numpy.float64'> 2
# installer__KUWASA , 0.0% nulls , <type 'numpy.float64'> 2
# installer__KYASHA ENTERPR , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Kaembe , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Kalago enterprises Co.Ltd , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Kalta , 0.0% nulls , <type 'numpy.float64'> 2
# installer__LGA , 0.0% nulls , <type 'numpy.float64'> 2
# installer__LVIA , 0.0% nulls , <type 'numpy.float64'> 2
# installer__LWI , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Lawatefuka water sup , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Losaa-Kia water supp , 0.0% nulls , <type 'numpy.float64'> 2
# installer__MA , 0.0% nulls , <type 'numpy.float64'> 2
# installer__MSF , 0.0% nulls , <type 'numpy.float64'> 2
# installer__MSF/TACARE , 0.0% nulls , <type 'numpy.float64'> 2
# installer__MTN , 0.0% nulls , <type 'numpy.float64'> 2
# installer__MUWSA , 0.0% nulls , <type 'numpy.float64'> 2
# installer__MWE , 0.0% nulls , <type 'numpy.float64'> 2
# installer__MWE & , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Ma , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Magadini-Makiwaru wa , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Makonde water population , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Miziriol , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Mw , 0.0% nulls , <type 'numpy.float64'> 2
# installer__NORAD , 0.0% nulls , <type 'numpy.float64'> 2
# installer__NULL , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Nandra Construction , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Ndanda missions , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Norad , 0.0% nulls , <type 'numpy.float64'> 2
# installer__OXFAM , 0.0% nulls , <type 'numpy.float64'> 2
# installer__OXFARM , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Oikos E .Africa , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Orien , 0.0% nulls , <type 'numpy.float64'> 2
# installer__P , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Pet Corporation Ltd , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Phase , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Pr , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Priva , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Private , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Quik , 0.0% nulls , <type 'numpy.float64'> 2
# installer__RC , 0.0% nulls , <type 'numpy.float64'> 2
# installer__RC CATHORIC , 0.0% nulls , <type 'numpy.float64'> 2
# installer__RC CHURCH , 0.0% nulls , <type 'numpy.float64'> 2
# installer__RC Ch , 0.0% nulls , <type 'numpy.float64'> 2
# installer__RC Church , 0.0% nulls , <type 'numpy.float64'> 2
# installer__RDC , 0.0% nulls , <type 'numpy.float64'> 2
# installer__RED CROSS , 0.0% nulls , <type 'numpy.float64'> 2
# installer__REGIONAL WATER ENGINEER ARUSHA , 0.0% nulls , <type 'numpy.float64'> 2
# installer__RIDEP , 0.0% nulls , <type 'numpy.float64'> 2
# installer__RWE , 0.0% nulls , <type 'numpy.float64'> 2
# installer__RWE/DWE , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Region water Department , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Regional Water , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Roman Church , 0.0% nulls , <type 'numpy.float64'> 2
# installer__SEMA , 0.0% nulls , <type 'numpy.float64'> 2
# installer__SHIPO , 0.0% nulls , <type 'numpy.float64'> 2
# installer__SI , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Save the rain USA , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Sekei village community , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Sengerema Water Department , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Shipo , 0.0% nulls , <type 'numpy.float64'> 2
# installer__St , 0.0% nulls , <type 'numpy.float64'> 2
# installer__TCRS , 0.0% nulls , <type 'numpy.float64'> 2
# installer__TPP , 0.0% nulls , <type 'numpy.float64'> 2
# installer__TWE , 0.0% nulls , <type 'numpy.float64'> 2
# installer__TWESA , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Tardo , 0.0% nulls , <type 'numpy.float64'> 2
# installer__UKILIG , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Ubung , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Unisef , 0.0% nulls , <type 'numpy.float64'> 2
# installer__VILLAGE COUNCIL , 0.0% nulls , <type 'numpy.float64'> 2
# installer__VWC , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Village Council , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Village govt , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Villagers , 0.0% nulls , <type 'numpy.float64'> 2
# installer__WATERAID , 0.0% nulls , <type 'numpy.float64'> 2
# installer__WD and ID , 0.0% nulls , <type 'numpy.float64'> 2
# installer__WEDECO , 0.0% nulls , <type 'numpy.float64'> 2
# installer__WORLD BANK , 0.0% nulls , <type 'numpy.float64'> 2
# installer__WORLD VISION , 0.0% nulls , <type 'numpy.float64'> 2
# installer__WU , 0.0% nulls , <type 'numpy.float64'> 2
# installer__WVT , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Wa , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Wachina , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Wananchi , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Water board , 0.0% nulls , <type 'numpy.float64'> 2
# installer__Wizara ya maji , 0.0% nulls , <type 'numpy.float64'> 2
# installer__World Vission , 0.0% nulls , <type 'numpy.float64'> 2
# installer__World vision , 0.0% nulls , <type 'numpy.float64'> 2
# installer__private , 0.0% nulls , <type 'numpy.float64'> 2
# installer__wanan , 0.0% nulls , <type 'numpy.float64'> 2
# installer__wananchi , 0.0% nulls , <type 'numpy.float64'> 2
# basin__Internal , 0.0% nulls , <type 'numpy.float64'> 2
# basin__Lake Nyasa , 0.0% nulls , <type 'numpy.float64'> 2
# basin__Lake Rukwa , 0.0% nulls , <type 'numpy.float64'> 2
# basin__Lake Tanganyika , 0.0% nulls , <type 'numpy.float64'> 2
# basin__Lake Victoria , 0.0% nulls , <type 'numpy.float64'> 2
# basin__Pangani , 0.0% nulls , <type 'numpy.float64'> 2
# basin__Rufiji , 0.0% nulls , <type 'numpy.float64'> 2
# basin__Ruvuma / Southern Coast , 0.0% nulls , <type 'numpy.float64'> 2
# basin__Wami / Ruvu , 0.0% nulls , <type 'numpy.float64'> 2
# region_code__1 , 0.0% nulls , <type 'numpy.float64'> 2
# region_code__11 , 0.0% nulls , <type 'numpy.float64'> 2
# region_code__12 , 0.0% nulls , <type 'numpy.float64'> 2
# region_code__13 , 0.0% nulls , <type 'numpy.float64'> 2
# region_code__14 , 0.0% nulls , <type 'numpy.float64'> 2
# region_code__15 , 0.0% nulls , <type 'numpy.float64'> 2
# region_code__16 , 0.0% nulls , <type 'numpy.float64'> 2
# region_code__17 , 0.0% nulls , <type 'numpy.float64'> 2
# region_code__18 , 0.0% nulls , <type 'numpy.float64'> 2
# region_code__19 , 0.0% nulls , <type 'numpy.float64'> 2
# region_code__2 , 0.0% nulls , <type 'numpy.float64'> 2
# region_code__20 , 0.0% nulls , <type 'numpy.float64'> 2
# region_code__21 , 0.0% nulls , <type 'numpy.float64'> 2
# region_code__24 , 0.0% nulls , <type 'numpy.float64'> 2
# region_code__3 , 0.0% nulls , <type 'numpy.float64'> 2
# region_code__4 , 0.0% nulls , <type 'numpy.float64'> 2
# region_code__6 , 0.0% nulls , <type 'numpy.float64'> 2
# region_code__60 , 0.0% nulls , <type 'numpy.float64'> 2
# region_code__7 , 0.0% nulls , <type 'numpy.float64'> 2
# region_code__8 , 0.0% nulls , <type 'numpy.float64'> 2
# region_code__80 , 0.0% nulls , <type 'numpy.float64'> 2
# region_code__9 , 0.0% nulls , <type 'numpy.float64'> 2
# region_code
, 0.0% nulls , <type 'numpy.float64'> 2
# ward__Nanga , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Nanganga , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Nangwa , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Nanjota , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Nanyumbu , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Naputa , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Ndola , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Nduguti , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Neruma , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Ngarenanyuki , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Ngasamo , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Ngh'ong'ona , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Ngonga , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Nguruka , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Ngwala , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Njombe Urban , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Njoro , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Nkiniziwa , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Nkoaranga , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Nkololo , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Nkoma , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Nkungulu , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Nshamba , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Nsimbo , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Nyaishozi , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Nyakabindi , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Nyakato , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Nyakitonto , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Nyalikungu , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Nyaluhande , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Nyamagaro , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Nyamhula , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Nyamirembe , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Nyang'hwale , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Nyanzenda , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Nyololo , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Nyoni , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Okoani Kibosho , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Old Moshi Mashariki , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Oldonyo Sambu , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Oldonyosambu , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Olmolog , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Oltroto , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Pahi , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Pande , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Pangani Mashariki , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Pito , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Qurus , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Rhotia , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Ring'wani , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Ruangwa , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Rubafu , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Rubale , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Rugu , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Ruhita , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Ruiwa , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Rujewa , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Ruponda , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Rusesa , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Rusumo , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Saja , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Sakasaka , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Sakwe , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Sandulula , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Sanjaranda , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Sapiwi , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Sasajila , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Sazira , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Sepuko , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Shimbi , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Shinghatini , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Shishiyu , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Siha Kaskazini , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Siha Kati , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Siha Magharibi , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Siha Mashariki , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Sikonge , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Simbo , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Sindano , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Sokoni II , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Somanda , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Somangira , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Songwa , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Sunga , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Sungaji , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Sunuka , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Tai , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Talaga , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Tambani , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Tungamaa , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Ubaruku , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Ubiri , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Ughandi , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Ukenyenge , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Ukwama , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Ulemo , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Uru Kaskazini , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Uru Shimbwe , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Usagara , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Ushiri Ikuini , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Usuka , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Utengule Usangu , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Utengule Usongwe , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Uvinza , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Uwemba , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Vigaeni , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Vikindu , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Wampelembe , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Wangama , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Zagayu , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Zinga/Ikerege , 0.0% nulls , <type 'numpy.float64'> 2
# ward__Zombo , 0.0% nulls , <type 'numpy.float64'> 2
# scheme_management__Company , 0.0% nulls , <type 'numpy.float64'> 2
# scheme_management__NULL , 0.0% nulls , <type 'numpy.float64'> 2
# scheme_management__Other , 0.0% nulls , <type 'numpy.float64'> 2
# scheme_management__Parastatal , 0.0% nulls , <type 'numpy.float64'> 2
# scheme_management__Private operator , 0.0% nulls , <type 'numpy.float64'> 2
# scheme_management__SWC , 0.0% nulls , <type 'numpy.float64'> 2
# scheme_management__VWC , 0.0% nulls , <type 'numpy.float64'> 2
# scheme_management__WUA , 0.0% nulls , <type 'numpy.float64'> 2
# scheme_management__WUG , 0.0% nulls , <type 'numpy.float64'> 2
# scheme_management__Water Board , 0.0% nulls , <type 'numpy.float64'> 2
# scheme_management__Water authority , 0.0% nulls , <type 'numpy.float64'> 2
# extraction_type__afridev , 0.0% nulls , <type 'numpy.float64'> 2
# extraction_type__climax , 0.0% nulls , <type 'numpy.float64'> 2
# extraction_type__gravity , 0.0% nulls , <type 'numpy.float64'> 2
# extraction_type__india mark ii , 0.0% nulls , <type 'numpy.float64'> 2
# extraction_type__ksb , 0.0% nulls , <type 'numpy.float64'> 2
# extraction_type__mono , 0.0% nulls , <type 'numpy.float64'> 2
# extraction_type__nira/tanira , 0.0% nulls , <type 'numpy.float64'> 2
# extraction_type__other , 0.0% nulls , <type 'numpy.float64'> 2
# extraction_type__other - play pump , 0.0% nulls , <type 'numpy.float64'> 2
# extraction_type__other - rope pump , 0.0% nulls , <type 'numpy.float64'> 2
# extraction_type__submersible , 0.0% nulls , <type 'numpy.float64'> 2
# extraction_type__swn 80 , 0.0% nulls , <type 'numpy.float64'> 2
# extraction_type__walimi , 0.0% nulls , <type 'numpy.float64'> 2
# extraction_type_group__afridev , 0.0% nulls , <type 'numpy.float64'> 2
# extraction_type_group__gravity , 0.0% nulls , <type 'numpy.float64'> 2
# extraction_type_group__india mark ii , 0.0% nulls , <type 'numpy.float64'> 2
# extraction_type_group__mono , 0.0% nulls , <type 'numpy.float64'> 2
# extraction_type_group__nira/tanira , 0.0% nulls , <type 'numpy.float64'> 2
# extraction_type_group__other , 0.0% nulls , <type 'numpy.float64'> 2
# extraction_type_group__rope pump , 0.0% nulls , <type 'numpy.float64'> 2
# extraction_type_group__submersible , 0.0% nulls , <type 'numpy.float64'> 2
# extraction_type_group__swn 80 , 0.0% nulls , <type 'numpy.float64'> 2
# extraction_type_class__gravity , 0.0% nulls , <type 'numpy.float64'> 2
# extraction_type_class__handpump , 0.0% nulls , <type 'numpy.float64'> 2
# extraction_type_class__motorpump , 0.0% nulls , <type 'numpy.float64'> 2
# extraction_type_class__other , 0.0% nulls , <type 'numpy.float64'> 2
# extraction_type_class__rope pump , 0.0% nulls , <type 'numpy.float64'> 2
# extraction_type_class__submersible , 0.0% nulls , <type 'numpy.float64'> 2
# management__company , 0.0% nulls , <type 'numpy.float64'> 2
# management__other - school , 0.0% nulls , <type 'numpy.float64'> 2
# management__parastatal , 0.0% nulls , <type 'numpy.float64'> 2
# management__private operator , 0.0% nulls , <type 'numpy.float64'> 2
# management__unknown , 0.0% nulls , <type 'numpy.float64'> 2
# management__vwc , 0.0% nulls , <type 'numpy.float64'> 2
# management__water authority , 0.0% nulls , <type 'numpy.float64'> 2
# management__water board , 0.0% nulls , <type 'numpy.float64'> 2
# management__wua , 0.0% nulls , <type 'numpy.float64'> 2
# management__wug , 0.0% nulls , <type 'numpy.float64'> 2
# management_group__commercial , 0.0% nulls , <type 'numpy.float64'> 2
# management_group__parastatal , 0.0% nulls , <type 'numpy.float64'> 2
# management_group__unknown , 0.0% nulls , <type 'numpy.float64'> 2
# management_group__user-group , 0.0% nulls , <type 'numpy.float64'> 2
# payment__never pay , 0.0% nulls , <type 'numpy.float64'> 2
# payment__other , 0.0% nulls , <type 'numpy.float64'> 2
# payment__pay annually , 0.0% nulls , <type 'numpy.float64'> 2
# payment__pay monthly , 0.0% nulls , <type 'numpy.float64'> 2
# payment__pay per bucket , 0.0% nulls , <type 'numpy.float64'> 2
# payment__pay when scheme fails , 0.0% nulls , <type 'numpy.float64'> 2
# payment__unknown , 0.0% nulls , <type 'numpy.float64'> 2
# payment_type__annually , 0.0% nulls , <type 'numpy.float64'> 2
# payment_type__monthly , 0.0% nulls , <type 'numpy.float64'> 2
# payment_type__never pay , 0.0% nulls , <type 'numpy.float64'> 2
# payment_type__on failure , 0.0% nulls , <type 'numpy.float64'> 2
# payment_type__other , 0.0% nulls , <type 'numpy.float64'> 2
# payment_type__per bucket , 0.0% nulls , <type 'numpy.float64'> 2
# payment_type__unknown , 0.0% nulls , <type 'numpy.float64'> 2
# water_quality__fluoride , 0.0% nulls , <type 'numpy.float64'> 2
# water_quality__milky , 0.0% nulls , <type 'numpy.float64'> 2
# water_quality__salty , 0.0% nulls , <type 'numpy.float64'> 2
# water_quality__salty abandoned , 0.0% nulls , <type 'numpy.float64'> 2
# water_quality__soft , 0.0% nulls , <type 'numpy.float64'> 2
# water_quality__unknown , 0.0% nulls , <type 'numpy.float64'> 2
# quality_group__fluoride , 0.0% nulls , <type 'numpy.float64'> 2
# quality_group__good , 0.0% nulls , <type 'numpy.float64'> 2
# quality_group__milky , 0.0% nulls , <type 'numpy.float64'> 2
# quality_group__salty , 0.0% nulls , <type 'numpy.float64'> 2
# quality_group__unknown , 0.0% nulls , <type 'numpy.float64'> 2
# quantity__dry , 0.0% nulls , <type 'numpy.float64'> 2
# quantity__enough , 0.0% nulls , <type 'numpy.float64'> 2
# quantity__insufficient , 0.0% nulls , <type 'numpy.float64'> 2
# quantity__seasonal , 0.0% nulls , <type 'numpy.float64'> 2
# quantity__unknown , 0.0% nulls , <type 'numpy.float64'> 2
# quantity_group__dry , 0.0% nulls , <type 'numpy.float64'> 2
# quantity_group__enough , 0.0% nulls , <type 'numpy.float64'> 2
# quantity_group__insufficient , 0.0% nulls , <type 'numpy.float64'> 2
# quantity_group__seasonal , 0.0% nulls , <type 'numpy.float64'> 2
# quantity_group__unknown , 0.0% nulls , <type 'numpy.float64'> 2
# source__dam , 0.0% nulls , <type 'numpy.float64'> 2
# source__hand dtw , 0.0% nulls , <type 'numpy.float64'> 2
# source__lake , 0.0% nulls , <type 'numpy.float64'> 2
# source__machine dbh , 0.0% nulls , <type 'numpy.float64'> 2
# source__other , 0.0% nulls , <type 'numpy.float64'> 2
# source__rainwater harvesting , 0.0% nulls , <type 'numpy.float64'> 2
# source__river , 0.0% nulls , <type 'numpy.float64'> 2
# source__shallow well , 0.0% nulls , <type 'numpy.float64'> 2
# source__spring , 0.0% nulls , <type 'numpy.float64'> 2
# source_type__borehole , 0.0% nulls , <type 'numpy.float64'> 2
# source_type__dam , 0.0% nulls , <type 'numpy.float64'> 2
# source_type__rainwater harvesting , 0.0% nulls , <type 'numpy.float64'> 2
# source_type__river/lake , 0.0% nulls , <type 'numpy.float64'> 2
# source_type__shallow well , 0.0% nulls , <type 'numpy.float64'> 2
# source_type__spring , 0.0% nulls , <type 'numpy.float64'> 2
# source_class__groundwater , 0.0% nulls , <type 'numpy.float64'> 2
# source_class__surface , 0.0% nulls , <type 'numpy.float64'> 2
# waterpoint_type__cattle trough , 0.0% nulls , <type 'numpy.float64'> 2
# waterpoint_type__communal standpipe , 0.0% nulls , <type 'numpy.float64'> 2
# waterpoint_type__communal standpipe multiple , 0.0% nulls , <type 'numpy.float64'> 2
# waterpoint_type__hand pump , 0.0% nulls , <type 'numpy.float64'> 2
# waterpoint_type__improved spring , 0.0% nulls , <type 'numpy.float64'> 2
# waterpoint_type__other , 0.0% nulls , <type 'numpy.float64'> 2
# waterpoint_type_group__cattle trough , 0.0% nulls , <type 'numpy.float64'> 2
# waterpoint_type_group__communal standpipe , 0.0% nulls , <type 'numpy.float64'> 2
# waterpoint_type_group__hand pump , 0.0% nulls , <type 'numpy.float64'> 2
# waterpoint_type_group__improved spring , 0.0% nulls , <type 'numpy.float64'> 2
# waterpoint_type_group__other , 0.0% nulls , <type 'numpy.float64'> 2

# %%
X_train.describe()
# Out:
#                  id     amount_tsh    gps_height     longitude      latitude  \
# count  59400.000000   59400.000000  59400.000000  59400.000000  5.940000e+04
# mean   37115.131768     317.650385    668.297239     34.077427 -5.706033e+00
# std    21453.128371    2997.574558    693.116350      6.567432  2.946019e+00
# min        0.000000       0.000000    -90.000000      0.000000 -1.164944e+01
# 25%    18519.750000       0.000000      0.000000     33.090347 -8.540621e+00
# 50%    37061.500000       0.000000    369.000000     34.908743 -5.021597e+00
# 75%    55656.500000      20.000000   1319.250000     37.178387 -3.326156e+00
# max    74247.000000  350000.000000   2770.000000     40.345193 -2.000000e-08
#
#         num_private   region_code  district_code    population  \
# count  59400.000000  59400.000000   59400.000000  59400.000000
# mean       0.474141     15.297003       5.629747    179.909983
# std       12.236230     17.587406       9.633649    471.482176
# min        0.000000      1.000000       0.000000      0.000000
# 25%        0.000000      5.000000       2.000000      0.000000
# 50%        0.000000     12.000000       3.000000     25.000000
# 75%        0.000000     17.000000       5.000000    215.000000
# max     1776.000000     99.000000      80.000000  30500.000000
#
#        construction_year
# count       59400.000000
# mean         1300.652475
# std           951.620547
# min             0.000000
# 25%             0.000000
# 50%          1986.000000
# 75%          2004.000000
# max          2013.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Variable Clean-up

# %% [markdown]
# ### Variables to delete

# %%
def removal():
    # id: we drop the id column because it is not a useful predictor.
    # 'amount_tsh' is mostly blank - delete
    # construction_year: we will delete this column since ~35% of the values are zeros.
    # wpt_name: not useful, delete (too many values)
    # subvillage: too many values, delete
    # scheme_name: this is almost 50% nulls, so we will delete this column
    # num_private: we will delete this column because ~99% of the values are zeros.
    # region: drop this b/c is seems very similar to region_code, though not 100% sure about this one!
    z = ['id', 'amount_tsh', 'num_private', 'construction_year', 'wpt_name', 
          'subvillage', 'scheme_name', 'region']
    for i in z:
        del X_train[i]
        del X_test[i]
    return

# %% [markdown]
# date_recorded: this might be a useful variable for this analysis, although the year itself would be useless in a practical scenario moving into the future. We will convert this column into a datetime, and we will also create 'year_recorded' and 'month_recorded' columns just in case those levels prove to be useful. A visual inspection of both casts significant doubt on that possibility, but we'll proceed for now. We will delete date_recorded itself, since random forest cannot accept datetime

# %%
def dates():
    for i in [X_train, X_test]:
        i['date_recorded'] = pd.to_datetime(i['date_recorded'])
        i['date_recorded'] = pd.to_datetime(i['date_recorded'])
        i['year_recorded'] = i['date_recorded'].apply(lambda x: x.year)
        i['month_recorded'] = i['date_recorded'].apply(lambda x: x.month)
        del i['date_recorded']
    return

# %% [markdown]
# `gps_height`, `latitude`, `longitude`

# %%
def locs():
    trans = ['longitude', 'latitude', 'gps_height', 'population']
    for i in [X_train, X_test]:
        i.loc[i.longitude == 0, 'latitude'] = 0
        for z in trans:
            i[z].replace(0., np.NaN, inplace = True)
            data = X_train.groupby(['district_code'])[z]
            i[z] = data.transform(lambda x: x.fillna(x.mean()))
        i['gps_height'].fillna(X_train['gps_height'].mean(), inplace = True)
        X_train['population'].fillna(X_train['population'].mean(), inplace = True)
    return

# %%
# public_meeting: we will fill the nulls as 'False'
# permit: we will fill the nulls as 'False'

def bools():
    z = ['public_meeting', 'permit']
    for i in z:
        X_train[i].fillna(False, inplace = True)
        X_train[i] = X_train[i].apply(lambda x: float(x))
        X_test[i].fillna(False, inplace = True)
        X_test[i] = X_test[i].apply(lambda x: float(x))
    return

# %% [markdown]
# string columns

# %%
def codes():
    # convert region_code and district_code to string objects, since they are actually categorical variables
    for i in ['region_code', 'district_code']:
        X_train[i] = X_train[i].apply(lambda x: str(x))
        X_test[i] = X_test[i].apply(lambda x: str(x))
    return

# %%
def dummies():
    global X_train, X_test
    columns = [i for i in X_train.columns if type(X_train[i].iloc[1]) == str]
    for column in columns:
        good_cols = []
        X_train[column].fillna('NULL', inplace = True)
        dumms = pd.get_dummies(X_train[column], prefix = column+'_')
        for i in dumms.columns:
        #    if chi2_contingency(pd.crosstab(dumms[i], y_train['status_group']))[1] < .001:
            good_cols.append(i)
        good_cols = [i for i in good_cols if i in pd.get_dummies(X_test[column], prefix = column+'_').columns]
        X_train = pd.concat((X_train, pd.get_dummies(X_train[column], prefix = column+'_')[good_cols]), axis = 1)
        X_test = pd.concat((X_test, pd.get_dummies(X_test[column], prefix = column+'_')[good_cols]), axis = 1)
        del X_train[column]
        del X_test[column]
    return

# %%
removal()

# %%
locs()

# %%
dates()

# %%
bools()

# %%
codes()

# %%
dummies()

# %%
np.shape(X_train)

# %%
np.shape(X_test)
# Out:
# (14850, 1115)

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(criterion='entropy',
                                n_estimators=100,
                                max_features='auto',
                                oob_score=True,
                                random_state=1,
                                n_jobs=-1)
                            
rf.fit(X_train, y_train.ravel())
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=100, n_jobs=-1, oob_score=True, random_state=1,
#             verbose=0, warm_start=False)

# %%
print "%.4f" % rf.oob_score_
# Out:
# 0.8044

# %%
predictions = rf.predict(X_test)
y_test = pd.read_csv('y_test.csv')
pred = pd.DataFrame(predictions, columns = [y_test.columns[1]])
del y_test['status_group']
y_test = pd.concat((y_test, pred), axis = 1)
y_test.to_csv('y_test.csv', sep=",", index = False)

# %% [markdown]
# ACTUAL SCORE: 0.7812

# %% [markdown]
# let's try dropping some of the lower-count columns...

# %%
for i in X_train.columns:
    if sum(X_train[i]) < 100:
        del X_train[i]
        del X_test[i]

# %%
print np.shape(X_train)
print np.shape(X_test)
# Out:
# (59400, 432)
# (14850, 432)

# %%
from sklearn.ensemble import RandomForestClassifier

rf2 = RandomForestClassifier(criterion='entropy',
                                n_estimators=500,
                                max_features='auto',
                                oob_score=True,
                                random_state=1,
                                n_jobs=-1)
                            
rf2.fit(X_train, y_train.ravel())
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=500, n_jobs=-1, oob_score=True, random_state=1,
#             verbose=0, warm_start=False)

# %%
print "%.4f" % rf2.oob_score_
# Out:
# 0.7941

# %%
predictions = rf2.predict(X_test)
y_test = pd.read_csv('y_test.csv')
pred = pd.DataFrame(predictions, columns = [y_test.columns[1]])
del y_test['status_group']
y_test = pd.concat((y_test, pred), axis = 1)
y_test.to_csv('y_test.csv', sep=",", index = False)

# %% [markdown]
# ACTUAL SCORE: 0.7701

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.ensemble import AdaBoostClassifier

tree = DecisionTreeClassifier(criterion='entropy', 
                              max_depth=1,
                              random_state=0)

ada = AdaBoostClassifier(base_estimator=tree,
                         n_estimators=900, 
                         learning_rate=.5,
                         random_state=0)

# %%
scores = cross_val_score(ada, X_train, y_train.values.ravel())

# %%
scores.mean()
# Out:
# 0.75670033670033676
