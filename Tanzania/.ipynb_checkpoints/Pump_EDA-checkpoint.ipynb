# %%
import pandas as pd
import numpy as np
import os
import timeit
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
X_train = pd.read_csv('X_train.csv')
y_train = pd.read_csv('y_train.csv')
X_test = pd.read_csv('X_test.csv')

# %% [markdown]
# Let's inspect our target variable:

# %%
del y_train['id']

# %%
sns.countplot(y_train['status_group'])

# %%
y_train['status_group'].value_counts(normalize = True)
# Out:
# functional                 0.543081
# non functional             0.384242
# functional needs repair    0.072677
# Name: status_group, dtype: float64

# %%
for i in X_train.columns:
    print i,',' ,'{:.1%}'.format(np.mean(X_train[i].isnull())),'nulls',',',type(X_train[i][0]), X_train[i].nunique()
# Out:
# id , 0.0% nulls , <type 'numpy.int64'> 59400
# amount_tsh , 0.0% nulls , <type 'numpy.float64'> 98
# date_recorded , 0.0% nulls , <type 'str'> 356
# funder , 6.1% nulls , <type 'str'> 1897
# gps_height , 0.0% nulls , <type 'numpy.int64'> 2428
# installer , 6.2% nulls , <type 'str'> 2145
# longitude , 0.0% nulls , <type 'numpy.float64'> 57516
# latitude , 0.0% nulls , <type 'numpy.float64'> 57517
# wpt_name , 0.0% nulls , <type 'str'> 37400
# num_private , 0.0% nulls , <type 'numpy.int64'> 65
# basin , 0.0% nulls , <type 'str'> 9
# subvillage , 0.6% nulls , <type 'str'> 19287
# region , 0.0% nulls , <type 'str'> 21
# region_code , 0.0% nulls , <type 'numpy.int64'> 27
# district_code , 0.0% nulls , <type 'numpy.int64'> 20
# lga , 0.0% nulls , <type 'str'> 125
# ward , 0.0% nulls , <type 'str'> 2092
# population , 0.0% nulls , <type 'numpy.int64'> 1049
# public_meeting , 5.6% nulls , <type 'bool'> 2
# recorded_by , 0.0% nulls , <type 'str'> 1
# scheme_management , 6.5% nulls , <type 'str'> 12
# scheme_name , 47.4% nulls , <type 'str'> 2696
# permit , 5.1% nulls , <type 'bool'> 2
# construction_year , 0.0% nulls , <type 'numpy.int64'> 55
# extraction_type , 0.0% nulls , <type 'str'> 18
# extraction_type_group , 0.0% nulls , <type 'str'> 13
# extraction_type_class , 0.0% nulls , <type 'str'> 7
# management , 0.0% nulls , <type 'str'> 12
# management_group , 0.0% nulls , <type 'str'> 5
# payment , 0.0% nulls , <type 'str'> 7
# payment_type , 0.0% nulls , <type 'str'> 7
# water_quality , 0.0% nulls , <type 'str'> 8
# quality_group , 0.0% nulls , <type 'str'> 6
# quantity , 0.0% nulls , <type 'str'> 5
# quantity_group , 0.0% nulls , <type 'str'> 5
# source , 0.0% nulls , <type 'str'> 10
# source_type , 0.0% nulls , <type 'str'> 7
# source_class , 0.0% nulls , <type 'str'> 3
# waterpoint_type , 0.0% nulls , <type 'str'> 7
# waterpoint_type_group , 0.0% nulls , <type 'str'> 6

# %%
X_train.describe()
# Out:
#                  id     amount_tsh    gps_height     longitude      latitude  \
# count  59400.000000   59400.000000  59400.000000  59400.000000  5.940000e+04
# mean   37115.131768     317.650385    668.297239     34.077427 -5.706033e+00
# std    21453.128371    2997.574558    693.116350      6.567432  2.946019e+00
# min        0.000000       0.000000    -90.000000      0.000000 -1.164944e+01
# 25%    18519.750000       0.000000      0.000000     33.090347 -8.540621e+00
# 50%    37061.500000       0.000000    369.000000     34.908743 -5.021597e+00
# 75%    55656.500000      20.000000   1319.250000     37.178387 -3.326156e+00
# max    74247.000000  350000.000000   2770.000000     40.345193 -2.000000e-08
#
#         num_private   region_code  district_code    population  \
# count  59400.000000  59400.000000   59400.000000  59400.000000
# mean       0.474141     15.297003       5.629747    179.909983
# std       12.236230     17.587406       9.633649    471.482176
# min        0.000000      1.000000       0.000000      0.000000
# 25%        0.000000      5.000000       2.000000      0.000000
# 50%        0.000000     12.000000       3.000000     25.000000
# 75%        0.000000     17.000000       5.000000    215.000000
# max     1776.000000     99.000000      80.000000  30500.000000
#
#        construction_year
# count       59400.000000
# mean         1300.652475
# std           951.620547
# min             0.000000
# 25%             0.000000
# 50%          1986.000000
# 75%          2004.000000
# max          2013.000000

# %% [markdown]
# ## Variable Clean-up

# %% [markdown]
# Note - keeping amount_tsh amounted to nothing!

# %%
def amount_tsh(X_train, X_test):
    """
    convert this item into a categorical variable
    """
    for i in [X_train, X_test]:
        i['amntsh'] = pd.qcut(X_train[X_train['amount_tsh'] <> 0]['amount_tsh'], 4)
        i['amntshnull'] = i['amntsh'].isnull().apply(lambda x: float(x))
    X_train = pd.concat((X_train, pd.get_dummies(X_train['amntsh'], prefix = 'amntsh')), axis = 1)
    X_test = pd.concat((X_test, pd.get_dummies(X_test['amntsh'], prefix = 'amntsh')), axis = 1)
    del X_train['amntsh']
    del X_test['amntsh']
    return X_train, X_test

# %% [markdown]
# ### Variables to delete

# %%
def removal():
    # id: we drop the id column because it is not a useful predictor.
    # 'amount_tsh' is mostly blank - delete
    # wpt_name: not useful, delete (too many values)
    # subvillage: too many values, delete
    # scheme_name: this is almost 50% nulls, so we will delete this column
    # num_private: we will delete this column because ~99% of the values are zeros.
    # region: drop this b/c is seems very similar to region_code, though not 100% sure about this one!
    z = ['id', 'num_private', 'wpt_name', 'subvillage', 'scheme_name', 'region', 
          'recorded_by', 'quantity', 'quality_group', 'source_type', 'payment', 'waterpoint_type_group',
         'extraction_type_group']
    for i in z:
        del X_train[i]
        del X_test[i]
    return

# %% [markdown]
# construction year: let's try filling in the nulls with the mean value

# %%
def construction():
    for i in [X_train, X_test]:
        i['construction_year'].replace(0, X_train[X_train['construction_year'] <> 0]['construction_year'].mean(), inplace=True)

# %%
construction()

# %%
def construction(X_train, X_test):
    """
    construction_year has 35% nulls, so we impute the nulls with the column mean
    """
    for i in [X_train, X_test]:
        i['construction_year'].replace(0., np.NaN, inplace = True)
        i['construction_year'].replace(1., np.NaN, inplace = True)
        data = X_train.groupby(['funder'])['construction_year']
        i['construction_year'] = data.transform(lambda x: x.fillna(x.mean()))
        data = X_train.groupby(['installer'])['construction_year']
        i['construction_year'] = data.transform(lambda x: x.fillna(x.mean()))
        i['construction_year'].fillna(X_train['construction_year'].mean(), inplace=True)
    return X_train, X_test

# %%
X_train, X_test = construction(X_train, X_test)

# %%
X_train['construction_year'].isnull().sum()/float(len(X_train))
# Out:
# 0.0

# %% [markdown]
# date_recorded: this might be a useful variable for this analysis, although the year itself would be useless in a practical scenario moving into the future. We will convert this column into a datetime, and we will also create 'year_recorded' and 'month_recorded' columns just in case those levels prove to be useful. A visual inspection of both casts significant doubt on that possibility, but we'll proceed for now. We will delete date_recorded itself, since random forest cannot accept datetime

# %%
def dates():
    for i in [X_train, X_test]:
        i['date_recorded'] = pd.to_datetime(i['date_recorded'])
        i['date_recorded'] = pd.to_datetime(i['date_recorded'])
        i['year_recorded'] = i['date_recorded'].apply(lambda x: x.year)
        i['month_recorded'] = i['date_recorded'].apply(lambda x: x.month)
        i['high_season'] = i['date_recorded'].apply(lambda x: 1 if x.month in [6, 7, 8, 9] else 0)
        i['low_season'] = i['date_recorded'].apply(lambda x: 1 if x.month in [2, 3, 4, 5] else 0)
        i['shoulder_season'] = i['date_recorded'].apply(lambda x: 1 if x.month in [10, 11, 12, 1] else 0)
        i['date_recorded'] = (pd.to_datetime(i['date_recorded'])).apply(lambda x: x.toordinal())
    return

# %%
dates()

# %% [markdown]
# `gps_height`, `latitude`, `longitude`

# %%
def locs():
    trans = ['longitude', 'latitude', 'gps_height', 'population']
    for i in [X_train, X_test]:
        i.loc[i.longitude == 0, 'latitude'] = 0
        for z in trans:
            i[z].replace(0., np.NaN, inplace = True)
            i[z].replace(1., np.NaN, inplace = True)
            data = X_train.groupby(['subvillage'])[z]
            i[z] = data.transform(lambda x: x.fillna(x.mean()))
            data = X_train.groupby(['district_code'])[z]
            i[z] = data.transform(lambda x: x.fillna(x.mean()))
            data = X_train.groupby(['basin'])[z]
            i[z] = data.transform(lambda x: x.fillna(x.mean()))
            i[z] = i[z].fillna(X_train[z].mean())
    return

# %%
locs()

# %%
# public_meeting: we will fill the nulls as 'False'
# permit: we will fill the nulls as 'False'

def bools():
    z = ['public_meeting', 'permit']
    for i in z:
        X_train[i].fillna(False, inplace = True)
        X_train[i] = X_train[i].apply(lambda x: float(x))
        X_test[i].fillna(False, inplace = True)
        X_test[i] = X_test[i].apply(lambda x: float(x))
    return

# %% [markdown]
# string columns

# %%
def codes():
    # convert region_code and district_code to string objects, since they are actually categorical variables
    for i in ['region_code', 'district_code']:
        X_train[i] = X_train[i].apply(lambda x: str(x))
        X_test[i] = X_test[i].apply(lambda x: str(x))
    return

# %%
def dummies():
    start = timeit.default_timer()
    global X_train, X_test
    columns = [i for i in X_train.columns if type(X_train[i].iloc[1]) == str]
    for column in columns:
        X_train[column].fillna('NULL', inplace = True)
        good_cols = [column+'_'+i for i in X_train[column].unique() if i in X_test[column].unique()]
        X_train = pd.concat((X_train, pd.get_dummies(X_train[column], prefix = column)[good_cols]), axis = 1)
        X_test = pd.concat((X_test, pd.get_dummies(X_test[column], prefix = column)[good_cols]), axis = 1)
        del X_train[column]
        del X_test[column]
    print timeit.default_timer() - start, 'seconds'
    return

# %%
removal()
dummies()
# Out:
# 65.5502892195 seconds

# %%
def meaningful():
    global X_train, X_test
    status = pd.get_dummies(y_train['status_group'])
    good_cols = []
    for i in X_train.columns[12:]:
        if status[X_train[i] == 1]['functional'].mean() > (status['functional'].mean() + .1):
            good_cols.append(i)
        elif status[X_train[i] == 1]['non functional'].mean() > (status['non functional'].mean() + .1):
            good_cols.append(i)
        elif status[X_train[i] == 1]['functional needs repair'].mean() > (status['functional needs repair'].mean() + .1):
            good_cols.append(i)
        X_train2 = pd.concat((X_train[:12], X_train[good_cols]), axis = 1)
        X_test2 = pd.concat((X_test[:12], X_test[good_cols]), axis = 1)
    return

# %%
construction()
locs()
dates()
bools()
codes()
removal()
dummies()

# %%
print np.shape(X_train)
print np.shape(X_test)
# Out:
# (59400, 3842)
# (14850, 3842)

# %%
y = pd.get_dummies(y_train)

# %%
a = pd.concat((X_train, y_train), axis = 1).pivot_table(values = 'year_recorded', index = 'month_recorded', columns = 'status_group'
                   , aggfunc = 'count')

# %%
sns.heatmap(a)

# %%
locs()

# %%
plt.figure(figsize=(10,4))
sns.countplot(pd.qcut(X_train['longitude'], 20), hue = y_train['status_group'])

# %%
plt.figure(figsize=(10,4))
sns.countplot(pd.qcut(X_train['latitude'], 20), hue = y_train['status_group'])

# %%
sns.countplot(pd.qcut(X_train['gps_height'], 20), hue = y_train['status_group'])

# %%
sns.countplot(pd.qcut(X_train['population'], 20), hue = y_train['status_group'])

# %%
plt.figure(figsize=(10,4))
sns.countplot(pd.qcut(X_train['date_recorded'], 20), hue = y_train['status_group'])

# %%
plt.figure(figsize=(10,4))
sns.countplot(X_train['month_recorded'], hue = y_train['status_group'])

# %% [markdown]
# ### Dataset 1

# %%
import feature_process_helper
import pandas as pd
import numpy as np
import os

# %%
X_train = pd.read_csv('X_train.csv')
y_train = pd.read_csv('y_train.csv')
X_test = pd.read_csv('X_test.csv')

# %%
X_train, X_test = feature_process_helper.dates(X_train, X_test)
X_train, X_test = feature_process_helper.construction(X_train, X_test)
X_train, X_test = feature_process_helper.bools(X_train, X_test)
X_train, X_test = feature_process_helper.locs(X_train, X_test)
X_train, X_test = feature_process_helper.removal(X_train, X_test)
X_train, X_test = feature_process_helper.dummies(X_train, X_test)

# %%
print np.shape(X_train)
print np.shape(X_test)
# Out:
# (59400, 2973)
# (14850, 2973)

# %%
X_train.to_csv(os.path.join('clean_data', 'X_train1.csv'), index = False)
X_test.to_csv(os.path.join('clean_data', 'X_test1.csv'), index = False)

# %% [markdown]
# ### Dataset 2

# %%
import feature_process_helper
import pandas as pd
import numpy as np
import os
from sklearn.externals import joblib

# %%
X_train = pd.read_csv('X_train.csv')
y_train = pd.read_csv('y_train.csv')
X_test = pd.read_csv('X_test.csv')

# %%
X_train, X_test = feature_process_helper.dates(X_train, X_test)
X_train, X_test = feature_process_helper.construction(X_train, X_test)
X_train, X_test = feature_process_helper.bools(X_train, X_test)
X_train, X_test = feature_process_helper.locs(X_train, X_test)
X_train, X_test = feature_process_helper.removal(X_train, X_test)
X_train, X_test = feature_process_helper.dummies(X_train, X_test)

# %%
corrs = {}

for i in X_train.columns:
    for z in X_train.columns:
        if i <> z and i.split('_') <> z.split('_') and i+'&'+z not in corrs and z+'&'+i not in corrs:
            if X_train[i].corr(X_train[z]) > .9:
                corrs[i+'&'+z] = X_train[i].corr(X_train[z])

# %%
joblib.dump(corrs, os.path.join('pickles', 'rf1_corr_dict.pkl'), 9)
# Out:
# ['pickles\\rf1_corr_dict.pkl']

# %%
plt.scatter(X_train['longitude'], X_train['latitude'], c=X_train['gps_height'])

# %% [markdown]
# ## LDA of continuous variables

# %% [markdown]
# First, let's see if our continuous predictors are normally distributed.

# %%
X_train['population'].hist()

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train_std = sc.fit_transform(X_train[['population', 'gps_height', 'latitude', 'longitude']])
#X_test_std = sc.transform(X_test)

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA

lda = LDA(n_components=None)
X_train_lda = lda.fit_transform(X_train_std, y_train.values.ravel())

lda.explained_variance_ratio_
# Out:
# array([ 0.7318153,  0.2681847])

# %%
X_train_std
# Out:
# array([[-0.52357278,  0.69297584, -1.43753978, -0.07821151],
#        [-0.16336724,  0.71042475,  1.33685452, -0.17117504],
#        [-0.22656119, -0.67191668,  0.73443628,  0.90165082],
#        ...,
#        [-0.15145754,  0.4760902 , -1.03953419, -0.43596498],
#        [ 0.41591069, -1.22368999, -0.18590848,  0.28040308],
#        [-0.43720771, -1.63160673, -0.31867124,  1.15156542]])

# %%
def lda(X_train, X_test, y_train):
    sc = StandardScaler()
    X_train_std = sc.fit_transform(X_train[['population', 'gps_height', 'latitude', 'longitude']])
    X_test_std = sc.transform(X_test[['population', 'gps_height', 'latitude', 'longitude']])
    lda = LDA(n_components=None)
    X_train_lda = lda.fit_transform(X_train_std, y_train.values.ravel())
    X_test_lda = lda.transform(X_test_std)
    X_train = pd.concat((pd.DataFrame(X_train_lda), X_train), axis=1)
    X_test = pd.concat((pd.DataFrame(X_test_lda), X_test), axis=1)
    return X_train, X_test

# %%
X_train, X_test = lda(X_train, X_test, y_train)

# %% [markdown]
# ## Impurity calculations of dummy variables

# %%
def gini(p):
    impurity = []
    for i in p:
        impurity.append(i**2)
    return 1-sum(impurity)

# %%
def impurity(X_train):
    imp = {}
    for i in X_train.columns[17:]:
        oney = y_train[X_train[i] == 1]['status_group']
        func = len(oney[oney == 'functional'])/float(len(oney))
        nonfunc = len(oney[oney == 'non functional'])/float(len(oney))
        rep = len(oney[oney == 'functional needs repari'])/float(len(oney))
        one = gini([func, nonfunc, rep])*X_train[X_train[i] == 1][i].mean()
        twoy = y_train[X_train[i] == 0]['status_group']
        func = len(twoy[twoy == 'functional'])/float(len(twoy))
        nonfunc = len(twoy[twoy == 'non functional'])/float(len(twoy))
        rep = len(twoy[twoy == 'functional needs repari'])/float(len(twoy))
        two = gini([func, nonfunc, rep])*(1-X_train[X_train[i] == 0][i].mean())
        imp[i] = one+two
    return imp

# %%
def impurity(X_train):
    imp = {}
    for i in X_train.columns[17:]:
        oney = y_train[X_train[i] == 1]['status_group']
        func = len(oney[oney == 'functional'])/float(len(oney))
        nonfunc = len(oney[oney == 'non functional'])/float(len(oney))
        rep = len(oney[oney == 'functional needs repari'])/float(len(oney))
        one = gini([func, nonfunc, rep])*X_train[i].mean()
        twoy = y_train[X_train[i] == 0]['status_group']
        func2 = len(twoy[twoy == 'functional'])/float(len(twoy))
        nonfunc2 = len(twoy[twoy == 'non functional'])/float(len(twoy))
        rep2 = len(twoy[twoy == 'functional needs repari'])/float(len(twoy))
        two = gini([func2, nonfunc2, rep2])*(1-X_train[i].mean())
        imp[i] = one+two
    return imp

# %%
babies = [i for i in X_train.columns if sum(X_train[i]) < 20]

# %%
len(babies)
# Out:
# 1911

# %%
imp = impurity(X_train)

# %%
imp['quantity_group_dry']
# Out:
# 0.4857251160008894

# %%
imp['installer_Cefa']
# Out:
# 0.5573309681814355

# %%
pd.crosstab(y_train['status_group'], columns=X_train['installer_Cefa'])
# Out:
# installer_Cefa             0.0  1.0
# status_group
# functional               32244   15
# functional needs repair   4317    0
# non functional           22824    0

# %%
imp
# Out:
# {'installer_HAAM': 0.5574096467290797,
#  'funder_Rural Drinking Water Supply': 0.5573755987037184,
#  'ward_Sekei': 0.5574200929782019,
#  'ward_Utengule Usangu': 0.5573560549334436,
#  'ward_Lutebe': 0.5571487315807699,
#  'funder_Koica': 0.5574182880479289,
#  'installer_Cefa': 0.5573309681814355,
#  'ward_Ruhembe': 0.5573882963662782,
#  'installer_COMMUNITY': 0.5574159615278003,
#  'funder_Ereto': 0.5573915810641035,
#  'ward_Mnyawa': 0.5573098700869931,
#  'ward_Mnero Miembeni': 0.5571030906314374,
#  'ward_Nata': 0.5573786454253743,
#  'installer_Tardo': 0.5571502347518525,
#  'ward_Mtowisa': 0.5574043795205611,
#  'funder_Diocese Of Geita': 0.5574062013834894,
#  'funder_African Development Foundation': 0.5573528981092877,
#  'funder_Jaica': 0.5573118658799477,
#  'ward_Misunkumilo': 0.557408994317055,
#  'ward_Mpambala': 0.557378988307128,
#  'ward_Miguwa': 0.5574193504067764,
#  'installer_Marafip': 0.5573528981092877,
#  'ward_Turwa': 0.5574191641934637,
#  'ward_Ulaya': 0.5573717401739742,
#  'installer_Rural Drinking Water Supply': 0.5573869484276576,
#  'ward_Kilangali': 0.557420150339666,
#  'ward_Mambali': 0.5573411980120592,
#  'ward_Ngongowele': 0.5573584829432758,
#  'ward_Orkesumet': 0.5573337877587834,
#  'installer_ACTIVE TANK CO': 0.5573669844885181,
#  'installer_DW': 0.5573613971409288,
#  'funder_Giz': 0.5572904587260697,
#  'ward_Murangi': 0.5574189717552349,
#  'ward_Mwembe': 0.5574121229482165,
#  'ward_Kidete': 0.5573538685837867,
#  'ward_Mngazi': 0.5574164834529814,
#  'funder_Plan Int': 0.5574113429383255,
#  'ward_Muungano': 0.5574208984722755,
#  'ward_Mlangali': 0.5572869879733651,
#  'funder_Quick': 0.5574194541638223,
#  'installer_DA': 0.5570638692591454,
#  'installer_Water Aid/sema': 0.5574147451634569,
#  'installer_DO': 0.5574200798733564,
#  'ward_Nishambya': 0.5574189403803662,
#  'funder_Menon': 0.5573919693190482,
#  'funder_Ox': 0.5574204816269364,
#  'installer_DH': 0.5574171059205316,
#  'ward_Bweni': 0.5573431494605935,
#  'ward_Nyangao': 0.557417277844449,
#  'ward_Lubiri': 0.5574200929782019,
#  'ward_Nyakasasa': 0.5574195227791556,
#  'ward_Idodi': 0.5573296021456244,
#  'ward_Kinyerezi': 0.55741345782485,
#  'funder_Abasia': 0.5573063064744479,
#  'ward_Makanya': 0.5573814156731596,
#  'ward_Mtanila': 0.5573959887485348,
#  'funder_Imf': 0.5573948357965633,
#  'installer_Da': 0.5567294362906181,
#  'installer_Do': 0.5574105778104856,
#  'funder_Acra': 0.5571447679272763,
#  'installer_TCRS/village community': 0.5574096467290797,
#  'ward_Bugandika': 0.5572961399340864,
#  'installer_Sangea District Coun': 0.557415320271465,
#  'ward_Namasakata': 0.5573851005068056,
#  'ward_Ngangamara': 0.5574200798733564,
#  'ward_Msitu wa Tembo': 0.5574157626479642,
#  'installer_RIDEP': 0.557332201869136,
#  'installer_Gwasco L': 0.5573800887237357,
#  'installer_COCANE': 0.5573705982284797,
#  'ward_Ugogoni': 0.5574183696389544,
#  'installer_IDEA': 0.5573609822760355,
#  'ward_Mbita': 0.5573342256246677,
#  'installer_TCRS /TWESA': 0.5573982977694382,
#  'installer_RWE/ Community': 0.5574025030133494,
#  'installer_Oikos E. Africa': 0.5573849899132756,
#  'ward_Mwaubingi': 0.5573393009136224,
#  'funder_Serikali': 0.5573880254163619,
#  'ward_Ukune': 0.5574133078323334,
#  'installer_Korogwe water works': 0.5573650182721072,
#  'funder_Rotary I': 0.5574029935192115,
#  'lga_Ukerewe': 0.556851449962191,
#  'basin_Lake Victoria': 0.5568936094636399,
#  'funder_Desk And Chair Foundation': 0.5574204225073043,
#  'funder_Village Council/ Haydom Luther': 0.5573429744257535,
#  'ward_Kitama': 0.5573503169728203,
#  'funder_Dhv': 0.5574073931111843,
#  'installer_World bank': 0.5574032576858857,
#  'funder_Tarangire Park': 0.5574149949128484,
#  'ward_Tumbi': 0.5573764571905764,
#  'ward_Njinjo': 0.557415663006781,
#  'ward_Malatu': 0.5573428728252255,
#  'ward_Mamsera': 0.5574033380990201,
#  'funder_Ham': 0.5574163709439551,
#  'ward_Kashenye': 0.5571712383017076,
#  'installer_NORA': 0.5573693605439679,
#  'lga_Morogoro Urban': 0.5573671070103436,
#  'ward_Igwamanoni': 0.5574191619791842,
#  'ward_Buswelu': 0.5573991846725932,
#  'lga_Dodoma Urban': 0.5564451372310084,
#  'funder_Cmcr': 0.5574057139218552,
#  'funder_Ai': 0.55732100676054,
#  'installer_TCRS a': 0.5574096467290797,
#  'ward_Shume': 0.5573476317085475,
#  'funder_Hesawa': 0.5566045205388856,
#  'ward_Kishanda': 0.5573942582926419,
#  'ward_Namanga': 0.5573902659337409,
#  'ward_Kilagano': 0.5574199916874482,
#  'funder_Salim Ahmed Salim': 0.5574149949128484,
#  'funder_Af': 0.5574179127096383,
#  'ward_Ikama': 0.5572754976438855,
#  'installer_LGCDG': 0.5574029935192115,
#  'funder_Twe': 0.5570462207485863,
#  'installer_BEMANDA': 0.5574149949128484,
#  'ward_Mzenga': 0.5572151563018565,
#  'ward_Msanga': 0.5573977660547275,
#  'funder_Hesawz': 0.5573965354360169,
#  'ward_Murungu': 0.5573870052727933,
#  'ward_Nondwa': 0.5573915690385357,
#  'installer_TCRS': 0.5569508913366784,
#  'ward_Magengati': 0.5574194541638223,
#  'ward_Mchinga': 0.5574184764210531,
#  'ward_Muhinda': 0.5573722650644798,
#  'ward_Pangale': 0.5574200929782019,
#  'funder_Ded': 0.5574005476541708,
#  'funder_Peace Cope': 0.5572053069724885,
#  'installer_Killflora /Community': 0.5574128007241053,
#  'funder_Sema': 0.5574035000382935,
#  'funder_Act': 0.5574149949128484,
#  'funder_Nduku Village': 0.5573869484276576,
#  'ward_Marungu': 0.5573986242531045,
#  'installer_Atlas Company': 0.5574178649871048,
#  'ward_Rhotia': 0.5572709248272196,
#  'ward_Ruzinga': 0.5573415472387574,
#  'ward_Sima': 0.5574093822451346,
#  'payment_type_annually': 0.5518320851024946,
#  'ward_Mnima': 0.5570803716804223,
#  'ward_Kahama Urban': 0.5574199189850609,
#  'funder_Kalitasi': 0.5573964049345517,
#  'ward_Iyogwe': 0.5573965354360169,
#  'funder_Dar Al Ber': 0.557345233934019,
#  'ward_Usevya': 0.5574205459994429,
#  'ward_Bukene': 0.557411709720989,
#  'funder_Dwe': 0.5572185121728771,
#  'ward_Sepeko': 0.5574043785193942,
#  'ward_Msia': 0.5573565235720982,
#  'installer_Handeni Trunk Main': 0.5574149949128484,
#  'installer_FinWater': 0.5573489761976507,
#  'ward_Tegeruka': 0.5574147451634569,
#  'ward_Ikungu': 0.5574103616209278,
#  'funder_Rudep': 0.5572979575746636,
#  'installer_Ubalozi wa Marekani': 0.5574204225073043,
#  "ward_Dung'unyi": 0.5572694416810331,
#  'installer_World vision': 0.5571330187615398,
#  'ward_Unyamikumbi': 0.5574173731880293,
#  'ward_Ifumbo': 0.5573415169921453,
#  'ward_Nyamatongo': 0.5573443870281763,
#  'ward_Endasak': 0.5574041652906174,
#  'ward_Kisangasa': 0.5573074923336753,
#  'funder_Ba As': 0.5573429744257535,
#  'ward_Luswisi': 0.5573609822760355,
#  'ward_Zongomera': 0.5574149354817909,
#  'funder_Drdp Ngo': 0.5573945756956097,
#  'ward_Kibedya': 0.5573851772541101,
#  'ward_Bargish': 0.5573519991603755,
#  'ward_Tchenzema': 0.557378988307128,
#  'ward_Kikombo': 0.5573503169728203,
#  'ward_Mkata': 0.5573846506493021,
#  'funder_Kiuma': 0.5573551061501009,
#  'ward_Ifunda': 0.5572464230938258,
#  'ward_Siha Mashariki': 0.5568998943842914,
#  'ward_Mahege': 0.5572023175254986,
#  'installer_Village Government': 0.5573729864988789,
#  'installer_Howard and humfrey consultant': 0.5573755987037184,
#  'funder_Bfwd': 0.5574149949128484,
#  'installer_FIN WATER': 0.5570842194172836,
#  'funder_Mwanga Town Water Authority': 0.5574168982912838,
#  'funder_Rwssp/wsdp': 0.5573975698324117,
#  'lga_Kilolo': 0.5573804174492397,
#  'ward_Kwedizinga': 0.5574150736031324,
#  'lga_Tarime': 0.5574092094981428,
#  'ward_Ndedo': 0.5574129570173718,
#  'funder_Living Water International': 0.5574117967615594,
#  'ward_Mahuninga': 0.5572989269588938,
#  'ward_Likokona': 0.5573321038093133,
#  'installer_Kiliwater': 0.5574067446604193,
#  'ward_Jangwani': 0.5574072757490567,
#  'ward_Kilema kaskazini': 0.557361392265721,
#  'installer_Vill': 0.557408343725529,
#  'funder_One Un': 0.5574193341246488,
#  'ward_Mwakitolyo': 0.5574083607821926,
#  'installer_Miomb': 0.5573869484276576,
#  'funder_Aict': 0.557255681057492,
#  'installer_FIDA': 0.5574096467290797,
#  'ward_Tulya': 0.5574189403803662,
#  'ward_Mailimoja': 0.5573676965952583,
#  'installer_RWE /Community': 0.5574164827529314,
#  'funder_Water Aid/sema': 0.5574202699899157,
#  'ward_Shangani': 0.5574199679126779,
#  'ward_Kinyagiri': 0.5574204937167682,
#  'funder_Kidep': 0.5574146022947016,
#  'funder_Msabi': 0.5573189611283846,
#  'installer_NCAA': 0.557412761220389,
#  'ward_Nainokanoka': 0.5573950058366005,
#  'funder_Oxfarm Gb': 0.5574096467290797,
#  'ward_Liuli': 0.5573416556669569,
#  'ward_Kitembe': 0.5573982977694382,
#  'ward_Simbo': 0.557367019954436,
#  'funder_Cspd': 0.5573994186432285,
#  'funder_Cdcg': 0.5574183696389544,
#  'ward_Ikowa': 0.5572762958971366,
#  'ward_Tandahimba': 0.5574078318124494,
#  'ward_Okoani Kibosho': 0.5572419352451188,
#  'funder_Mkuyu': 0.5573766180063436,
#  'installer_RUDEP': 0.5574137793213917,
#  'ward_Nyakibimbili': 0.5574179127096383,
#  'lga_Iramba': 0.557294528420312,
#  'ward_Kasungamile': 0.5574042914254296,
#  'lga_Kiteto': 0.5569239946089917,
#  'ward_Chilangala': 0.5572507265124088,
#  'ward_Makata': 0.5573671988677797,
#  'ward_Kaagya': 0.5574203166633073,
#  'installer_kanisa': 0.5574149949128484,
#  'installer_China': 0.5573642485976015,
#  'ward_Mlangarini': 0.5572702817421802,
#  'funder_No': 0.5572727997331076,
#  'ward_Kiberege': 0.5574045211209128,
#  'funder_Nk': 0.5574016175358106,
#  'installer_Dr. Matobola': 0.5573969925193072,
#  'ward_Yaeda Chini': 0.5574184752539078,
#  'ward_Misima': 0.5574003504039873,
#  'lga_Ngara': 0.5573646201626357,
#  'funder_Prf': 0.5573489772446633,
#  'installer_CAP': 0.5574149949128484,
#  'ward_Nzuguni': 0.5573662840617802,
#  'lga_Meru': 0.5571414263058609,
#  'ward_Mkambalani': 0.5573961248015953,
#  'funder_Community': 0.5573080978979857,
#  'funder_Bruder': 0.557383330390664,
#  'ward_Riroda': 0.5573705982284797,
#  'ward_Nitekela': 0.5574163965761461,
#  'funder_Tacare': 0.5574124648591176,
#  'ward_Luchelegwa': 0.5572203286975153,
#  'installer_Ga': 0.5573896635558924,
#  'source_other': 0.557410585183443,
#  'installer_HOLLAND': 0.5572923260497231,
#  'installer_Mpang': 0.5573687119959031,
#  'funder_Cocern': 0.5574172944557563,
#  'installer_Go': 0.5573942919798679,
#  'funder_Kuwasa': 0.5571918208486659,
#  'funder_Peters': 0.5574177561731043,
#  'funder_Action Aid': 0.5574200798733564,
#  'installer_UN': 0.5573228183450843,
#  'funder_Lions Club': 0.5573965354360169,
#  'ward_Mahembe': 0.5571473650257149,
#  'ward_Shelui': 0.5573958139783387,
#  'lga_Hanang': 0.5572804444878798,
#  'installer_SIJM': 0.5573720714469158,
#  'installer_VILLAGERS': 0.5574189717552349,
#  'funder_Lotary Club': 0.5574060931548557,
#  'ward_Msalato': 0.5573528981092877,
#  'funder_Tado': 0.5573249647560068,
#  'ward_Pugu': 0.5574092165200941,
#  'ward_Nyakabindi': 0.5573729249216505,
#  'funder_Compasion International': 0.5574149949128484,
#  'ward_Kasanga': 0.5574184660919939,
#  'ward_Ngarenanyuki': 0.5568358719041949,
#  'funder_Finwater': 0.5573659429312426,
#  'ward_Bombo': 0.5574163709439551,
#  'installer_Unicef': 0.5574179127096383,
#  'ward_Puge': 0.5574022413354132,
#  'funder_Rc': 0.556731730565904,
#  'funder_Snv': 0.5573917729283763,
#  'installer_Kibaha Town Council': 0.5574029935192115,
#  'ward_Kikomero': 0.5574125810678551,
#  'ward_Kwediboma': 0.5572986547581074,
#  'ward_Mkowe': 0.557344249580429,
#  'ward_Mkomazi': 0.5573818917995801,
#  'installer_Kiliflora': 0.5573687119959031,
#  'ward_Buyango': 0.5574003725972004,
#  'installer_TANAP': 0.5574153531271975,
#  'installer_TANAS': 0.5574029935192115,
#  'ward_Msogezi': 0.5574073759432652,
#  'funder_Ballo': 0.5574149949128484,
#  'installer_wanan': 0.5572135257390868,
#  'installer_central government': 0.5573781325910276,
#  'funder_Fida': 0.5574096467290797,
#  'ward_Goima': 0.5573093524494575,
#  'installer_Summit for water/Community': 0.557378988307128,
#  'installer_TWE': 0.5570107629767094,
#  'ward_Lundi': 0.557420870686523,
#  'installer_Total landcare': 0.5573965354360169,
#  'ward_Ngudu': 0.5573958254626595,
#  'ward_Janda': 0.5573649133959591,
#  'funder_Dioce': 0.557408994317055,
#  'ward_Image': 0.5573744827769668,
#  'lga_Nkasi': 0.5567479961945822,
#  'installer_Action Aid': 0.5574149949128484,
#  'ward_Kilakala': 0.5574077024751337,
#  'ward_Rwinga': 0.5573584599574998,
#  'installer_Italy government': 0.5574127668251109,
#  'ward_Mombo': 0.5574178620073508,
#  'ward_Kilago': 0.5573922005940901,
#  'ward_Utengule Usongwe': 0.5573246367510911,
#  'installer_Adra/ Community': 0.5572650656474952,
#  'ward_Kimamba A': 0.5573966731117409,
#  'ward_Kahororo': 0.5573908224661054,
#  'installer_RWE/DWE': 0.5570590369374658,
#  'installer_TAG': 0.557415654269586,
#  'funder_Livin': 0.5573910089715693,
#  'ward_Keni  Alleni': 0.557375242231988,
#  'ward_Bumilayinga': 0.5573416592736223,
#  'installer_Wizara ya maji': 0.5571141746299417,
#  'ward_Mgungira': 0.5574163965761461,
#  'ward_Unyambwa': 0.5573953234251688,
#  'ward_Sokon I': 0.5574199679126779,
#  'ward_Kimamba B': 0.5574149698808213,
#  'installer_WATER  AID': 0.5573609822760355,
#  'installer_KKKT-Dioces ya Pare': 0.5573074923336753,
#  'scheme_management_WUG': 0.5565169176855892,
#  'ward_Mcholi II': 0.5574127668251109,
#  'ward_Chikongola': 0.5573909913173318,
#  'ward_Lupila': 0.5571525978341709,
#  'ward_Kimnyaki': 0.5574176552208293,
#  'installer_MUWASA': 0.5573960136340752,
#  'installer_Kkkt': 0.557408994317055,
#  'installer_wizara ya maji': 0.557408994317055,
#  'ward_Nyaluhande': 0.5572939993431976,
#  'funder_Rdc': 0.5572393722010622,
#  'ward_Kalunde': 0.5574128007241053,
#  'ward_Mpotwa': 0.5573953319620323,
#  'installer_PIDP': 0.5573856626852131,
#  'lga_Mvomero': 0.5570513088328274,
#  'funder_Council': 0.557420578977633,
#  'ward_Kilima Rondo': 0.5572272187134503,
#  'ward_Ilolo Mpya': 0.557308570174316,
#  'funder_School': 0.5574025030133494,
#  'ward_Mtego wa Noti': 0.5573169121752027,
#  'installer_CH': 0.5574149949128484,
#  'funder_Rural Water Supply And Sanitat': 0.5573864773787824,
#  'ward_Laela': 0.557415045756941,
#  'funder_Mmem': 0.5574020700974083,
#  'ward_Rusesa': 0.5573830928047175,
#  'ward_Bubiki': 0.5573965354360169,
#  'ward_Kingale': 0.5573993883164773,
#  'installer_CITIZEN ENGINE': 0.5573975536350538,
#  'ward_Misalai': 0.5574182880479289,
#  'funder_Mdc': 0.5574155749614907,
#  'ward_Manza': 0.5574025030133494,
#  'ward_Mahurunga': 0.5574142731329267,
#  'ward_Irole': 0.5573225830166016,
#  'ward_Luhunga': 0.5573990558213716,
#  'installer_MCHOME': 0.5573869484276576,
#  'ward_Marambo': 0.5573258226249183,
#  'ward_Bashay': 0.5574108708133971,
#  'ward_Lalago': 0.5573128864494408,
#  'ward_Kitongo Sima': 0.5573373630287333,
#  'funder_Devon Aid Korogwe': 0.5573794110721809,
#  'funder_Mamlaka Ya Maji Ngara': 0.5573862683951585,
#  'ward_Shishani': 0.5574176139446948,
#  'installer_CIPRO/CARE': 0.5574186423726804,
#  'ward_Maramba': 0.5570920279474312,
#  'installer_Nyamongo Gold mining': 0.5573969925193072,
#  'ward_Mbutu': 0.5573604828277726,
#  'ward_Chona': 0.5574195657628922,
#  'ward_Kabita': 0.5574103114336357,
#  'installer_Institution': 0.5573729864988789,
#  'ward_Ikinga': 0.5574070564857638,
#  'ward_Olgosorok': 0.5574200429867242,
#  'ward_Nyambureti': 0.5574173565021063,
#  'funder_Hewasa': 0.5574064782562467,
#  'funder_Dbfpe': 0.5573869484276576,
#  'installer_GEN': 0.5574080862547456,
#  'installer_SDA': 0.5573511893827131,
#  'installer_Serikali ya kijiji': 0.557415654269586,
#  'ward_Machame Mashariki': 0.5573245678269886,
#  'installer_COMMU': 0.5574062013834894,
#  'ward_Naintiri': 0.5573985474286086,
#  'funder_Oikos E.Afrika': 0.556787440091775,
#  'ward_Lamaiti': 0.5573944069577025,
#  'installer_LVA Ltd': 0.557378988307128,
#  'funder_Tasaf': 0.557409931681921,
#  'installer_Mwanga town water authority': 0.5574168982912838,
#  'installer_Miziriol': 0.5571723792924994,
#  'ward_Nanguruwe': 0.5574161455632324,
#  'installer_Individual': 0.5574204816269364,
#  'installer_AMREF': 0.5573097916271367,
#  'installer_Plan Int': 0.5574070564857638,
#  'ward_Lake Jipe': 0.5572734339879507,
#  'ward_Igombavanu': 0.5574201947599612,
#  'ward_Itobo': 0.5573265679663368,
#  'installer_Tasaf': 0.5574164827529314,
#  'installer_Consuting Engineer': 0.5573772271971131,
#  'ward_Dihimba': 0.5574071958624578,
#  'installer_LGA': 0.5566335064859091,
#  'installer_Region water Department': 0.5566047690002143,
#  'ward_Kinole': 0.5573685689912306,
#  'ward_Mwandeti': 0.5573577271720184,
#  'ward_Keni Mengeni': 0.5574190696087841,
#  'ward_Binagi': 0.5573834960727208,
#  'funder_Tridep': 0.5573766075587151,
#  'installer_Samsoni': 0.5574149949128484,
#  'installer_Wasso contractors': 0.5574186423726804,
#  'funder_Songas': 0.5573736060916261,
#  'ward_Gombero': 0.5573642485976015,
#  'ward_Goribe': 0.5574029935192115,
#  'funder_H/w': 0.5574127668251109,
#  'funder_Cocen': 0.5574058525461268,
#  'ward_Daa': 0.5573189611283846,
#  'ward_Nyankanga': 0.5573627449029253,
#  'ward_Hogoro': 0.5574169101541733,
#  'funder_Pentecosta Church': 0.5574200929782019,
#  'funder_Miomb': 0.5573869484276576,
#  'basin_Wami / Ruvu': 0.5571314620476284,
#  'ward_Nangomba': 0.5573981870165058,
#  'ward_Kalemela': 0.5574182482668235,
#  'funder_German Missionary': 0.5574149949128484,
#  'ward_Ikuwo': 0.5573669844885181,
#  'funder_Ddp': 0.557419251016776,
#  'extraction_type_ksb': 0.5571219859279996,
#  'funder_Adf': 0.5574194541638223,
#  'funder_Robert Loyal': 0.5573849899132756,
#  'installer_Tanz': 0.5574176197558756,
#  'ward_Chalangwa': 0.5573668905646796,
#  'source_river': 0.556065294038111,
#  'installer_Active KMK': 0.5574149949128484,
#  'ward_Gidahababieg': 0.5574204816269364,
#  'funder_Vodacom': 0.5574200929782019,
#  'ward_Kisongo': 0.5573198923729523,
#  'ward_Mnekachi': 0.5573244855091396,
#  'installer_Action Contre La Faim': 0.5574128007241053,
#  'installer_KKT': 0.5573952241603461,
#  'funder_Adp': 0.5573632110579478,
#  'basin_Internal': 0.5571105092571312,
#  'installer_ADRA': 0.55733019724586,
#  'extraction_type_gravity': 0.5489888192202352,
#  'ward_Mishamo': 0.5566711585178591,
#  'ward_Matekwe': 0.5573415472387574,
#  'installer_RUDE': 0.5574003504039873,
#  'funder_Kigoma Municipal': 0.5574207016711437,
#  'installer_Rished': 0.5573642485976015,
#  'ward_Nyamilama': 0.5573452161238364,
#  'ward_Malya': 0.5574018971845985,
#  'ward_Bujugo': 0.5573987743198372,
#  'lga_Serengeti': 0.5573891473568927,
#  'ward_Kipeta': 0.5573301959859913,
#  'ward_Sasajila': 0.5572251598475254,
#  'ward_Mkuyuni': 0.557410699591677,
#  'funder_Government Of Tanzania': 0.5511920597176709,
#  'installer_Regional Water': 0.5572507265124088,
#  'ward_Mibulani': 0.5574032078658279,
#  'ward_Lukanga': 0.5574159540127506,
#  'installer_TA': 0.5574200788919202,
#  'funder_Chamavita': 0.5574111335615798,
#  'ward_Ruhunga': 0.5574046124581828,
#  'installer_TASSAF/ TCRS': 0.5574149949128484,
#  'ward_Siuyu': 0.5573521812580415,
#  'installer_LOCAL CONTRACT': 0.5574206117577537,
#  'installer_BRUDER': 0.557383330390664,
#  'installer_Mkuyu': 0.5573766180063436,
#  'ward_Ilonga': 0.5574109269922949,
#  'funder_Private Owned': 0.5573628944520232,
#  'installer_Rundu man': 0.5574163965761461,
#  'ward_Uvinza': 0.557383641221231,
#  'ward_Samuye': 0.557414119329331,
#  'ward_Igalla': 0.5573167877588979,
#  'ward_Machame Kaskazini': 0.5572973391238457,
#  'ward_Iduo': 0.5572393722010622,
#  'ward_Kafule': 0.5573609822760355,
#  'installer_Ta': 0.5574096467290797,
#  'installer_Chamavita': 0.5573659043021876,
#  'ward_Ushirika': 0.557392256636663,
#  'installer_DBFPE': 0.5573869484276576,
#  'ward_Mtama': 0.5573498437096894,
#  'funder_Norad/government': 0.5574149949128484,
#  'installer_CPRO': 0.5574164143327371,
#  'funder_Germany Misionary': 0.5573802455680413,
#  'installer_Msabi': 0.55732170809313,
#  "ward_Nyang'hwale": 0.5571223719928858,
#  'installer_SHY BUILDERS': 0.557380146416499,
#  'ward_Lubiga': 0.55740856319361,
#  'ward_Suma': 0.5573867380251739,
#  'ward_Tuwemacho': 0.5574200788126767,
#  'funder_Halmashauri Ya Wilaya': 0.5574020700974083,
#  'ward_Ukondamoyo': 0.5574003504039873,
#  'ward_Boma': 0.557408994317055,
#  'ward_Ilangala': 0.5573970562850684,
#  'funder_Oxfam': 0.5571407200580495,
#  'funder_Cdtfdistrict Council': 0.5574106132539918,
#  'ward_Berega': 0.5573814800919156,
#  'installer_RUDEP/': 0.5573720714469158,
#  'ward_Luponde': 0.5572262751240395,
#  'installer_TAN PLANT LTD': 0.5573339789473685,
#  'lga_Bukoba Urban': 0.5574197506832556,
#  'ward_Miangalua': 0.5573887573107923,
#  'installer_MBWAMBO': 0.5574204816269364,
#  'funder_Private Individual': 0.5553947221260581,
#  'ward_Kitobo': 0.5574186909421548,
#  'ward_Goweko': 0.5574198495343792,
#  'ward_Idahina': 0.5574182880479289,
#  'installer_KKKT CHURCH': 0.5573939313182418,
#  'ward_Hedaru': 0.5573310216663424,
#  'ward_Imesela': 0.5573977660547275,
#  'installer_KYASHA ENTERPR': 0.5574036828782335,
#  'ward_Issenye': 0.5574207995612236,
#  'funder_Institution': 0.5573744985042721,
#  'installer_villagers': 0.557414837871756,
#  'installer_SERONERA': 0.5574149949128484,
#  'ward_Unga Ltd': 0.5574191905586491,
#  'ward_Uyowa': 0.5574084932906531,
#  'ward_Kwala': 0.5574179127096383,
#  'ward_Nyachiluluma': 0.5573875219154568,
#  'ward_Kilindoni': 0.5573120577369748,
#  'funder_Rural Water Department': 0.5573982977694382,
#  'installer_VILLAGE COUNCIL': 0.5573022860966357,
#  'installer_KIM KIM CONSTRUCTION': 0.5572053069724885,
#  'ward_Kahe Mashariki': 0.5572143067910491,
#  'funder_Plan': 0.5574149949128484,
#  'ward_Mbede': 0.5574093822451346,
#  'funder_Village Government': 0.5573620685773517,
#  'ward_Lengatei': 0.5573184354804416,
#  'funder_Shipo': 0.5570648709719839,
#  'lga_Musoma Rural': 0.5570314108134425,
#  'installer_Unknown': 0.5574200929782019,
#  'funder_School Adm9nstrarion': 0.557408994317055,
#  'ward_Koryo': 0.5573908716320289,
#  'ward_Ndumbwe': 0.5573554054513776,
#  'ward_Mwaniko': 0.557404885899957,
#  'ward_Kibanga': 0.5573756743782555,
#  'funder_Cafod': 0.5572867278557232,
#  'funder_Cmsr': 0.5574157672561499,
#  'ward_Nanjota': 0.5571202865313231,
#  'installer_Halmashauri ya wilaya': 0.5574020700974083,
#  'ward_Nkungulu': 0.5573298846526297,
#  'installer_Killflora/ Community': 0.5574204078571123,
#  'ward_Ngwelo': 0.5574200798733564,
#  'ward_Njengwa': 0.5573882849708127,
#  'ward_Kituntu': 0.557415654269586,
#  'ward_Bukome': 0.5574204079862441,
#  'ward_Kidodi': 0.5571137660744016,
#  'lga_Kigoma Rural': 0.5566471635354132,
#  'funder_Cipro/government': 0.5573584139130039,
#  'installer_Sao': 0.557336971404681,
#  'lga_Shinyanga Rural': 0.5574058431954416,
#  'ward_Kamachumu': 0.5574003071304624,
#  'ward_Mbokomu': 0.5573348158260275,
#  'installer_Brad': 0.5574149949128484,
#  'ward_Missungwi': 0.5574094776512926,
#  'ward_Itetemia': 0.5573237304149159,
#  'ward_Kwakoa': 0.557413574666046,
#  'ward_Lagana': 0.5573892785573455,
#  'ward_USA River': 0.5573588837978873,
#  'installer_Village council': 0.5574029935192115,
#  'ward_Ushetu': 0.5574153859072277,
#  'ward_Sunga': 0.5572910054125622,
#  'ward_Natta': 0.5574150773061515,
#  'funder_Missio': 0.557408994317055,
#  'ward_Chingungwe': 0.5573891254222808,
#  'ward_Ussoke': 0.5574193049387951,
#  'ward_Kirongo Samanga': 0.5573818917995801,
#  'ward_Masaki': 0.5574096438984627,
#  'management_vwc': 0.550290562788784,
#  'installer_FW': 0.5559277194650137,
#  'funder_Oikos E.Africa/european Union': 0.5572501923916852,
#  'installer_BENGUKA': 0.557357066993267,
#  'ward_Idamba': 0.557372183934905,
#  'source_hand dtw': 0.5573998093822159,
#  'lga_Nanyumbu': 0.5568893865431805,
#  'installer_NYAKILANGANI CONSTRUCTION': 0.5574200929782019,
#  'funder_Amref': 0.5570893843806743,
#  'installer_TAWASA': 0.5574167927698034,
#  'ward_Uyovu': 0.5574206273258905,
#  'ward_Busagara': 0.5574079578705627,
#  'ward_Ngasamo': 0.5574064201635168,
#  'installer_EMANDA BUILDERS': 0.5574096467290797,
#  'ward_Chipanga': 0.557384006360617,
#  'ward_Iwindi': 0.5574080862547456,
#  'ward_Katazi': 0.5573977660547275,
#  'installer_AIMGOLD': 0.5573669844885181,
#  'ward_Mzizima': 0.5574083607821926,
#  'installer_Rotery c': 0.5574149949128484,
#  'ward_Chakwale': 0.5572106281777419,
#  'ward_Imalinyi': 0.5561897175827487,
#  'ward_Kileo': 0.5573966695301007,
#  'ward_Kalebezo': 0.5573784204233522,
#  'installer_BSF': 0.5574195117421766,
#  'ward_Mwakanshashala': 0.5573799980396641,
#  'ward_Bunambiu': 0.5574053283278964,
#  'installer_Ardhi water well': 0.5573074923336753,
#  'ward_Nyabubinza': 0.5574050139953756,
#  'ward_Bunamhala': 0.5574005890201688,
#  'installer_WORLD BANK': 0.556997893293861,
#  'ward_Muhukuru': 0.5574139058344666,
#  'installer_Milenium': 0.5574029935192115,
#  'funder_Roman Cathoric-same': 0.5574077374390632,
#  'installer_Village  Council': 0.5573969925193072,
#  'funder_Unesco': 0.5574147446143506,
#  'ward_Lyabukande': 0.5574194878571876,
#  'ward_Gairo': 0.5573998841812983,
#  'installer_IDYDC': 0.5574155799686263,
#  'ward_Lunguza': 0.5574195654241513,
#  'installer_LIVI': 0.5573957483396736,
#  'funder_Co': 0.5573256283565953,
#  'installer_WINNIN SPIRIT CO': 0.5573982977694382,
#  'installer_G.D&I.D': 0.5574096467290797,
#  'funder_Ch': 0.5574149949128484,
#  'funder_Cg': 0.5574178886728155,
#  'ward_Ilunde': 0.5574093822451346,
#  'ward_Mengwe Manda': 0.5573756374735781,
#  'ward_Gungu': 0.5573650100479471,
#  'ward_Ilunda': 0.5573221509229764,
#  'ward_Luhundwa': 0.5574146103859653,
#  'ward_Vinghawe': 0.5574003504039873,
#  'ward_Igongwa': 0.5573707868513359,
#  'installer_CHINA Co.': 0.5574149949128484,
#  'ward_Lunguya': 0.5574071958624578,
#  'ward_Mrijo': 0.5574120444664954,
#  'installer_SAXON': 0.557414837871756,
#  'ward_Mabawe': 0.557415302498671,
#  'installer_Ngiresi village community': 0.5574029935192115,
#  'ward_Babayu': 0.557418426562306,
#  'ward_Ilagala': 0.5573933072197961,
#  'ward_Likunja': 0.557270973308714,
#  'ward_Bupandwamhela': 0.5574173948634817,
#  'ward_Ilolangulu': 0.5573657974167004,
#  'installer_Exaud Msambwa': 0.5573993883164773,
#  'ward_Makorongo': 0.5574081668754566,
#  'ward_Matanga': 0.5572166624311214,
#  'ward_Namichinga': 0.5574077024751337,
#  'payment_type_monthly': 0.5512085907170162,
#  'installer_DMDD': 0.5572991404753832,
#  'ward_Kurui': 0.5573375136247289,
#  'installer_Central Government': 0.5571569660170603,
#  'ward_Rubeho': 0.5574102335991636,
#  'ward_Maligisu': 0.5574142961456089,
#  'lga_Liwale': 0.5568967788279641,
#  'funder_Christian Outrich': 0.5574168982912838,
#  'ward_Mambwekenya': 0.5573711513178595,
#  'installer_Halmashauli': 0.5574147446143506,
#  'installer_MARAFIP': 0.55734044527596,
#  'installer_Counc': 0.557419251016776,
#  'funder_Ministry Of Healthy': 0.5574204816269364,
#  'ward_Kijima': 0.557378988307128,
#  'ward_Mwanjoro': 0.5573850212854254,
#  'ward_Lemara': 0.5574062013834894,
#  'ward_Nampungu': 0.5574084932906531,
#  'ward_Nyabiyonza': 0.5574180486012219,
#  'funder_Rc Mission': 0.5574109274100014,
#  'ward_Bukabwa': 0.5574163965761461,
#  'ward_Kafunzo': 0.557415320271465,
#  'ward_Nanganga': 0.5572638007028757,
#  'ward_Mtipa': 0.5573570520392951,
#  'ward_Kibamba': 0.5573188443509705,
#  'installer_KUWAIT': 0.5572299869823789,
#  'ward_Chalinze': 0.5571442360318715,
#  'funder_De': 0.5573954607533493,
#  'management_wua': 0.5553664999185971,
#  'ward_Itonjanda': 0.5573914054676615,
#  'ward_Shitage': 0.5574200929782019,
#  'ward_Mugunzu': 0.5574000396771923,
#  'funder_Handeni Trunk Main(': 0.5574125810678551,
#  'funder_Mem': 0.5574022413354132,
#  'ward_Haneti': 0.5573940843997097,
#  'funder_Kkkt_makwale': 0.5574129230833548,
#  'lga_Manyoni': 0.5567182833349704,
#  'installer_MAKE ENGINEERING': 0.5573869484276576,
#  'funder_Cipro': 0.5574159615278003,
#  'installer_Pata': 0.5573909913173318,
#  'funder_Msikiti': 0.5573375136247289,
#  'ward_Mlali': 0.5573818074523689,
#  'funder_Asb': 0.557312957298559,
#  'installer_Jika': 0.557408994317055,
#  'funder_Netherla': 0.5574096467290797,
#  'ward_Mlalo': 0.5574096438984627,
#  'installer_MOSQUE': 0.5574149949128484,
#  'installer_Halmashauri': 0.5573784204233522,
#  'ward_Shishiyu': 0.5573588542516373,
#  'ward_Loibor Siret': 0.5574149701023785,
#  'installer_FPCT': 0.5573933805485854,
#  'ward_Ulanda': 0.5574195123876765,
#  'ward_Ndolwa': 0.5574184092522628,
#  'ward_Bariadi': 0.5573944877704118,
#  'payment_type_other': 0.5572927274329855,
#  'installer_Oldadai village community': 0.5574200929782019,
#  'installer_DWE': 0.5572627791937044,
#  'ward_Berege': 0.557418426562306,
#  'funder_Serikali Ya Kijiji': 0.5573915690385357,
#  'lga_Kilwa': 0.556662962743107,
#  'installer_USA EMBASSY': 0.5574149949128484,
#  'installer_RCchurch/CEFA': 0.5573993073379221,
#  'ward_Machame Uroki': 0.5572674939799322,
#  'installer_ABASIA': 0.5573608272444375,
#  'ward_Nahukahuka': 0.5573757593930848,
#  'water_quality_salty abandoned': 0.5573465624436391,
#  'installer_KONOIKE': 0.557378988307128,
#  'funder_Colonial Government': 0.5574029935192115,
#  'ward_Fukalo': 0.5574189403803662,
#  'ward_Mwadobana': 0.5573560043651006,
#  'lga_Chato': 0.5574136023764134,
#  'funder_Happy Watoto Foundation': 0.5573508327336018,
#  'funder_Partage': 0.557401861517958,
#  'ward_Kwaluguru': 0.5574124081067287,
#  'ward_Kebanchabancha': 0.5574092035458672,
#  'ward_Miteja': 0.5572431793770506,
#  'installer_Roman Cathoric -Same': 0.5573982977694382,
#  'funder_Dwe/norad': 0.5574200513985687,
#  'lga_Shinyanga Urban': 0.5574198197507256,
#  'ward_Iyogela': 0.557413857087144,
#  'ward_Nkumba': 0.5573719513388453,
#  'ward_Nsimbo': 0.557255867980541,
#  'ward_Nyamimange': 0.5574070542202786,
#  'ward_Kikubiji': 0.5573863079391416,
#  'funder_Mianz': 0.5574029935192115,
#  'funder_Ces(gmbh)': 0.5561018707272513,
#  'ward_Ngoma': 0.5573843566329423,
#  'ward_Madimba': 0.5574183057414247,
#  'funder_Halmashauri': 0.5573647163362185,
#  'installer_Water Aid/DWE': 0.5574096467290797,
#  'ward_Vudee': 0.5574027785431604,
#  'ward_Ibadakuli': 0.557419674605565,
#  'basin_Rufiji': 0.5552394763390919,
#  'ward_Heka Azimio': 0.5574204816269364,
#  'ward_Mtekente': 0.5574201442253068,
#  'ward_Busawe': 0.5573113339915086,
#  'ward_Murray': 0.5574159615278003,
#  'installer_Recoda': 0.5574096467290797,
#  'installer_Losaa-Kia water supp': 0.5571767552995188,
#  'funder_Halmashauri Ya Manispa Tabora': 0.5573671988677797,
#  'ward_Nyandekwa': 0.5574185073717547,
#  'funder_World Vision/ Kkkt': 0.5574077024751337,
#  'installer_DWR': 0.5574009314196726,
#  'ward_Namtuhuka': 0.5572382100443943,
#  'funder_Fredked Conservation': 0.5574149949128484,
#  'lga_Songea Rural': 0.5573593190346728,
#  'installer_ADP': 0.5574201501435226,
#  'installer_Kuwait': 0.557409255466045,
#  'funder_Eu/acra': 0.557312957298559,
#  'ward_Machinjioni': 0.5574096467290797,
#  'funder_Dct': 0.557375992206179,
#  'funder_Tirdo': 0.5574147446143506,
#  'ward_Masela': 0.5574189969094906,
#  'scheme_management_VWC': 0.5539375252763872,
#  'funder_Ilct': 0.5574130281936591,
#  'ward_Ngima': 0.5574189717552349,
#  'ward_Mima': 0.5574135638976495,
#  'funder_Lowasa': 0.5573744985042721,
#  'ward_Mwaru': 0.5573915690385357,
#  'ward_Dabil': 0.5573664037799335,
#  "ward_Ng'ambo": 0.5574200929782019,
#  'funder_Rafik': 0.557408994317055,
#  'ward_Uyui': 0.5574199679126779,
#  'ward_Kahangara': 0.5573818917995801,
#  'funder_Po': 0.5574015674685205,
#  'lga_Kilombero': 0.5574136724647204,
#  'ward_Kibasuka': 0.5573849899132756,
#  'ward_Bwisya': 0.5573992492712485,
#  'ward_Mwera': 0.5572762775001617,
#  'installer_District water depar': 0.5574050549061171,
#  'installer_AI': 0.5573321038093133,
#  'ward_Nyoni': 0.5573042496700028,
#  'installer_AC': 0.557408994317055,
#  'installer_AD': 0.5573628944520232,
#  'installer_W/': 0.5573655053468625,
#  'installer_AF': 0.5573755987037184,
#  'installer_WUA': 0.5573729864988789,
#  'ward_Zirai': 0.5574025030133494,
#  'ward_Mawengi': 0.5571602342209304,
#  'ward_Utende': 0.5573732041212339,
#  'installer_TRIDEP': 0.5573642485976015,
#  'ward_Nangwa': 0.5572681089146476,
#  'installer_Wananchi': 0.557294106720418,
#  'lga_Mbozi': 0.5569891882927434,
#  'installer_MDALA Contractor': 0.5573849899132756,
#  'installer_WB': 0.5574175143722896,
#  'lga_Ileje': 0.5573204094359597,
#  'ward_Itwangi': 0.5574190029786108,
#  'ward_Kifanya': 0.5573880300509818,
#  'installer_WE': 0.5573909913173318,
#  'ward_Busole': 0.557415099239189,
#  'ward_Chipuputa': 0.5574093822451346,
#  'installer_OLA': 0.5573755987037184,
#  'funder_Mtuwasa And Community': 0.5574029935192115,
#  'installer_WU': 0.5565644675499384,
#  'ward_Gelai Lumbwa': 0.5574192182923009,
#  'funder_Care International': 0.5573290274409414,
#  'ward_Izimbya': 0.5574154747712998,
#  'installer_Oikos E.Afrika': 0.5573909913173318,
#  'installer_Wa': 0.5572764025293974,
#  'funder_Tcrs /government': 0.5574081690022998,
#  'funder_Roman Ca': 0.5574081690022998,
#  'ward_Mwamanongu': 0.5574046437189043,
#  'ward_Mchukwi': 0.5574038030921692,
#  'ward_Masqaroda': 0.5573910089715693,
#  'installer_Wo': 0.5574080751260925,
#  'installer_Morovian': 0.5574149949128484,
#  'ward_Buyagu': 0.5574086702250061,
#  'installer_Milenia': 0.557418426562306,
#  'funder_Railway': 0.5574159615278003,
#  'ward_Namagondo': 0.557249511790182,
#  'installer_DUWAS': 0.5573729864988789,
#  'installer_Kijiji': 0.557408994317055,
#  'installer_Colonial government': 0.5574149949128484,
#  'funder_Wfp/usaid': 0.5574029935192115,
#  'ward_Mkamba': 0.5572830406240382,
#  'ward_Bwera': 0.5574196827601613,
#  'installer_Private': 0.5572759472162918,
#  'installer_Government': 0.554387188860512,
#  'funder_Olgilai Village Community': 0.5574184752539078,
#  'ward_Madilu': 0.5571996952511838,
#  'ward_Misughaa': 0.5573880915495242,
#  'installer_VILLAG': 0.5573411250469361,
#  'installer_DDCA': 0.557352147249151,
#  'funder_Wfp': 0.5573136400661338,
#  'installer_Water': 0.5573952642520007,
#  'ward_Misozwe': 0.5574188074496194,
#  'funder_Fathe': 0.5571988460995922,
#  'ward_Kyanyari': 0.5574163598107793,
#  'lga_Mbulu': 0.5573520224437268,
#  'funder_Lions': 0.5574168982912838,
#  'ward_Dunda': 0.5574077024751337,
#  'installer_Free Pentecoste Church of Tanz': 0.5573969925193072,
#  'ward_Mngoyo': 0.5574204079862441,
#  'installer_US Embassy': 0.5573957483396736,
#  'funder_Bs': 0.5573757593930848,
#  'ward_Ilungu': 0.5573777443949945,
#  'funder_Gain': 0.5574195858759363,
#  'ward_Dosidosi': 0.5574022413354132,
#  'funder_Rc Church': 0.5565560643696595,
#  'funder_Global Fund': 0.5573982977694382,
#  'ward_Muyama': 0.5573198015347548,
#  'ward_Bujonde': 0.5569028279090332,
#  'installer_MLADE': 0.5573748876222282,
#  'installer_KEREBUKA': 0.5574029935192115,
#  'ward_Kisesa': 0.5574175448734757,
#  'ward_Kisese': 0.5573940141839566,
#  'funder_Sangea District Council': 0.557415320271465,
#  'installer_DCT': 0.5574025030133494,
#  'ward_Bugogwe': 0.5573650100479471,
#  'ward_Kiluvya': 0.5573849899132756,
#  'installer_Af': 0.5574154590111642,
#  'ward_Kiloleli': 0.5573407572439911,
#  'water_quality_soft': 0.5500075313854247,
#  'ward_Msindo': 0.557274342369115,
#  'installer_Roman Catholic Rulenge Diocese': 0.5574169937661881,
#  'installer_VWC': 0.5571237177415834,
#  'installer_Adra /Community': 0.5572830938077378,
#  'ward_Milingoti Mashariki': 0.5573965354360169,
#  'installer_FINI WATER': 0.5567509180978494,
#  'funder_Villagers': 0.5572589627274835,
#  'ward_Bulungwa': 0.5574191893667131,
#  'ward_Mbinga Urban': 0.5573456633158892,
#  'ward_Paranga': 0.5573971198725349,
#  'ward_Pemba': 0.5574087026049543,
#  'installer_AAR': 0.557400230502207,
#  'ward_Chanika': 0.5573898260465519,
#  'installer_TASAF': 0.5574084987561194,
#  'ward_Idifu': 0.557415320271465,
#  'ward_Mkoka': 0.5573427554430483,
#  'installer_The desk and chair foundat': 0.5574018971845985,
#  'installer_COBASHEC': 0.5573869484276576,
#  'ward_Chala': 0.5573563740548657,
#  'installer_Kirdep': 0.5573642485976015,
#  'ward_Kigombe': 0.5572740759932607,
#  'ward_Bashinet': 0.5574099311252566,
#  'ward_Nandembo': 0.5573852093887295,
#  'lga_Kibondo': 0.5574037776717008,
#  'installer_RC church/Central Gover': 0.5574185172906251,
#  'installer_O &': 0.5574096467290797,
#  'installer_Village': 0.557378988307128,
#  'ward_Mwawaza': 0.5574109645777687,
#  'ward_Kinyeto': 0.5572737566176748,
#  'ward_Mbugani': 0.5573725323406549,
#  'funder_Cristan Outrich': 0.5574149949128484,
#  'ward_Mji Mwema': 0.5574134321379988,
#  'ward_Mantare': 0.5573786454253743,
#  'ward_Olbolot': 0.5573757593930848,
#  'funder_Kanisa': 0.5573669844885181,
#  'installer_Railway': 0.5574159615278003,
#  'lga_Babati': 0.556591772377388,
#  'installer_Mackd': 0.5573309681814355,
#  'ward_Mtenga': 0.5573979345957005,
#  'lga_Bahi': 0.5572909253653981,
#  'ward_Bukombe': 0.5573385009839819,
#  'funder_Nazareth Church': 0.557408994317055,
#  'ward_Kipili': 0.5574200788126767,
#  'installer_GACHUMA GINERY': 0.5574029935192115,
#  'ward_Kazaroho': 0.5574188074496194,
#  'installer_LWI': 0.5572767352838721,
#  'installer_Wachina': 0.5573045001753292,
#  'ward_Lubanga': 0.5573416592736223,
#  'ward_Rushwa': 0.5574124081067287,
#  'ward_Mikumi': 0.557391666199579,
#  'ward_Mtwango': 0.5571538616229039,
#  'ward_Kinjumbi': 0.5573257209283902,
#  'funder_W.D &': 0.5573528981092877,
#  'ward_Mhezi': 0.5573969925193072,
#  'ward_Qurus': 0.5570971394807281,
#  'ward_Nalasi': 0.5574155749614907,
#  'funder_Kanisa Katoliki Lolovoni': 0.5573809892392769,
#  'source_shallow well': 0.5548748448583399,
#  'funder_Eung-am Methodist Church': 0.5574149949128484,
#  'ward_Kirwa Keni': 0.5572246478452998,
#  'installer_KMCL': 0.5573609822760355,
#  'ward_Chiugutwa': 0.557124937266691,
#  'installer_Claver': 0.5574149949128484,
#  'ward_Kiusa': 0.557408994317055,
#  'funder_Unicef/cspd': 0.557408994317055,
#  'ward_Uyumbu': 0.5574184660919939,
#  'ward_Nakapanya': 0.5573711513178595,
#  'ward_Mwamalasa': 0.5573942582926419,
#  'ward_Kasoli': 0.5573924400515881,
#  'installer_Handeni Trunk Main(': 0.5574094409948673,
#  'ward_Msangeni': 0.5573301959859913,
#  'funder_Quick Wins': 0.5573570520392951,
#  'installer_Artisan': 0.5574200752143045,
#  'ward_Mpuguso': 0.5571871939966063,
#  'funder_Rc/mission': 0.5573909913173318,
#  'funder_Wateraid': 0.557071062700856,
#  'funder_Private Institutions': 0.5574149949128484,
#  'ward_Muhuwesi': 0.557335571695982,
#  'ward_Kalangalala': 0.5574093506950722,
#  'basin_Lake Tanganyika': 0.5569469166381867,
#  'funder_Tltc': 0.5574189403803662,
#  'installer_Roman': 0.5574079280497006,
#  'installer_Romam': 0.5574149949128484,
#  'ward_Ntendo': 0.5574094304216897,
#  'ward_Nyamiyaga': 0.5573882849708127,
#  'extraction_type_class_wind-powered': 0.557361934126015,
#  'source_dam': 0.5567261700519274,
#  'funder_African': 0.5574129813155513,
#  'ward_Tabaruka': 0.557418426562306,
#  'ward_Lupalilo': 0.5569437189942918,
#  'ward_Mlondwe': 0.5573609822760355,
#  'source_spring': 0.5522333794071277,
#  'ward_Igurusi': 0.5573106132667347,
#  'ward_Chiola': 0.5573516135627168,
#  'ward_Kaselya': 0.5574205764606514,
#  'installer_JANDU PLUMBER CO': 0.5574176911172081,
#  'ward_Mofu': 0.5573922005940901,
#  'ward_Kibirizi': 0.5573489761976507,
#  'ward_Sunya': 0.557365334322548,
#  'ward_Nambambo': 0.5573619447263557,
#  'funder_Dasip': 0.5574186670341684,
#  'funder_Hifab': 0.5571085742925438,
#  'water_quality_coloured': 0.5574068832082145,
#  'funder_Mheza Distric Counc': 0.5574194541638223,
#  'ward_Komuge': 0.5569984317048045,
#  'ward_Mshewe': 0.5574107151365405,
#  'ward_Mshewa': 0.5573849099352132,
#  'ward_Nambinzo': 0.5573860376205396,
#  'ward_Bonde la Songwe': 0.5572910525691768,
#  'installer_WEDECO/WESSONS': 0.5573975698324117,
#  'ward_Machame Magharibi': 0.5573451929004396,
#  'funder_Kuamu': 0.5573919144898566,
#  'ward_Dongo': 0.5573305548521088,
#  'ward_Chela': 0.5572466105219062,
#  'ward_Kinampanda': 0.5574193049387951,
#  'ward_Kachwamba': 0.557249511790182,
#  'ward_Mwika Kusini': 0.5573828961865727,
#  'installer_MISSION': 0.5574204225073043,
#  'ward_Bukiriro': 0.5573295776350967,
#  'ward_Kandete': 0.5573524202810203,
#  'funder_Solar Villa': 0.5573982977694382,
#  'ward_Mnara': 0.5573856626852131,
#  'funder_Pidp': 0.5573981870165058,
#  'funder_Clause': 0.5574151973654449,
#  'ward_Kiwangwa': 0.5573671326856646,
#  'funder_Village Community': 0.557413126345812,
#  'ward_Mtibwa': 0.557416924124048,
#  'ward_Busisi': 0.5574163965761461,
#  'ward_Sepuko': 0.5571884380375561,
#  'funder_Rc Church/centr': 0.5574185172906251,
#  'ward_Bwawani': 0.5573382308514462,
#  'ward_Mkwiti': 0.557408994317055,
#  'ward_Kasanda': 0.5574150697438541,
#  'ward_Bujashi': 0.5572199971616002,
#  'ward_Kyamuraile': 0.5574162892010655,
#  'installer_DESK C': 0.5574125810678551,
#  'funder_Total Land Care': 0.5574169101541733,
#  'installer_Concern': 0.5573621338507163,
#  'ward_Itinje': 0.5573978593031786,
#  'ward_Lutale': 0.5573480902932841,
#  'installer_LVIA': 0.5573764311466536,
#  'funder_Norad/ Kidep': 0.5574135638976495,
#  'ward_Nyakahura': 0.5574203424334818,
#  'funder_Mbozi District Council': 0.5574140333220529,
#  'funder_Japan': 0.5572788463250105,
#  'installer_Vi': 0.5574200929782019,
#  'ward_Lupanga': 0.5574034919244333,
#  'funder_Tassaf/ Danida': 0.5573849899132756,
#  'ward_Muze': 0.5573812592241312,
#  'installer_WILLIAMSON DIAMOND LTD': 0.5574086702250061,
#  'funder_Suwasa': 0.557418426562306,
#  'ward_Kalinzi': 0.5572881955347672,
#  'ward_Mabamba': 0.5574203163036813,
#  'extraction_type_other - rope pump': 0.5572948523059493,
#  'ward_Kakonko': 0.5572331994706806,
#  'funder_Bgss': 0.5574149949128484,
#  'funder_Kerebuka': 0.557408994317055,
#  'installer_Clause workers': 0.5574151973654449,
#  'funder_World Bank/government': 0.5574096467290797,
#  ...}

# %%
plt.plot(range(3600,len(imp)), sorted(imp.values())[3600:][::-1])

# %%
plt.plot(range(2000, len(imp)), sorted(imp.values())[::-1][2000:])

# %%
plt.plot(range(200, 2500), sorted(imp.values())[::-1][200:2500])
